# %%
from semanticscholar import SemanticScholar
from crossref.restful import Works
from itertools import product
import pandas as pd
import json
import dblp 
import requests
import time
from requests import HTTPError

# %%
# old search params

# https://crfm.stanford.edu/helm/lite/latest/#/leaderboard Jan 2, 2024
# llm_stanford = [
#     "GPT-4",
#     "GPT-4-Turbo", 
#     "Palmyra-X-V3",
#     "Palmyra-X", #base
#     "Palmyra", #base
#     "PaLM-2 unicorn", #unicorn
#     "PaLM 2", #base
#     "PaLM", #base
#     "Palmyra-X-V2",
#     "Palmyra X", #base
#     "Yi 6B",
#     "Mixtral 8x7B",
#     "Mixtral", #base
#     "Claude v1.3",
#     "Claude", #base
#     "PaLM-2 bison", #bison
#     "Claude 2.0",
#     "Llama 2",
#     "Llama", #base
#     "text-davinci-003",
#     "text-davinci", #base
#     "Claude 2.1",
#     "Claude", #base
#     "Claude Instant 1.2",
#     "text-davinci-002",
# ]
# 
# # https://huggingface.co/spaces/lmsys/chatbot-arena-leaderboard Jan 2, 2024
# llm_arena_elo = [
#     "GPT-4-Turbo",
#     "GPT-4-0314",
#     "GPT-4-0613",
#     "Claude 1",
#     "Claude 2.0",
#     "Mixtral-8x7b-Instruc",
#     "Mixtral-8x7b", #base
#     "Claude 2.1",
#     "GPT-3.5-Turbo-0613",
#     "GPT-3.5-Turbo", #base
#     "GPT-3.5", #base
#     "GPT-3", #base
#     "GPT", #base
#     "Gemini Pro",
#     "Gemini", #base
#     "Claude-Instant-1",
#     "Claude-Instant",
#     "Tulū-2-DPO-70B",
#     "Tulū 2",  #base
#     "Yi-34B-Chat",
#     "Yi 34B", #base
#     "GPT-3.5-Turbo-0314",
#     "WizardLM-70B-v1.0",
#     "WizardLM",#base
#     "Vicuna-33B"
#     "Vicuna",
# ]
# 
# llms = llm_stanford + llm_arena_elo
# llms = list(set(llms))

# %%
# search params
primary_keywords = [
    "Generative Artificial Intelligence",
    "Generative AI",
    "GenAI",
    "Gen AI",
    "LLM",
    "LM",
    "SLM",
    "SLMs",
    "LLMs",
    "CLM",
    "CLMs",
    "large language model",
    "language model",
    "small language model",
    "compact language model",
    "foundation model",
    
]

secondary_keywords1 = ["mitigation", "ethics", "societal", "social", "ethical"]

secondary_keywords2 = ["Computing Education", "Computer Science Education", "CSEd", "CER"]


tertiary_keywords = [
    "overreliance",
    "over-reliance",
    "misinformation",
    "accessibility",
    "privacy",
    "environmental",
    "explainability",
    "trustworthy",
    "responsible",
]

start_year = "2017"
sch_year = start_year + "-"
crossref_year = start_year
years = ["2017", "2018", "2019", "2020", "2021", "2022", "2023"]
dblp_formatted_years = " " + "|".join(f"{year}" for year in years)
wos_years = "2017-01-01+2023-12-31"

all_combinations = list(product(primary_keywords, secondary_keywords2, tertiary_keywords))

# %%
# Prepare DataFrame to store the results
columns = [
    'PaperTitle',
    'ID',    
    'SearchString',
    'SearchedFrom',
]
search_results_df = pd.DataFrame(columns=columns)

# %%
# helper functions
sch = SemanticScholar()
# SemanticScholar fields
sch_fields = [
    "title",
    "externalIds",
    "paperId",
    "url",
    "authors",
]

def sch_get_paper_id(sch_result):
    if sch_result['externalIds'].get('DOI') is None:
        if sch_result['externalIds'].get('ArXiv') is None:
            sch_paper_id = "paperid:" + sch_result.get("paperId")
        else:
            sch_paper_id = "DOI:10.48550/arXiv." + sch_result['externalIds'].get('ArXiv')
    else:
        sch_paper_id = f"DOI:{sch_result['externalIds'].get('DOI')}"
        
    return sch_paper_id


def search_semantic_scholar(bulk: bool=False, search_string: str=None, fields=sch_fields, year: str=None):
    if bulk:
        api_url = "https://api.semanticscholar.org/graph/v1/paper/search/bulk"
    else:
        api_url = "https://api.semanticscholar.org/graph/v1/paper/search"
    
    headers = {"Content-Type": "application/json", "x-api-key": "X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5"}
    sch_search_string = search_string
    if fields == "all":
        params = {"query": sch_search_string, "year": year}
    else:
        params = {"query": sch_search_string, "year": year, "fields": ",".join(fields)}
    print("headers:", headers)
    print("params:", params)
    response = requests.get(api_url, headers=headers, params=params)
    while response.status_code != 200:
        print(f"Semantic Scholar response status code: {response.status_code}, waiting 30 seconds...")
        time.sleep(30)
        response = requests.get(api_url, headers=headers, params=params)
    response_json = response.json()
    return response_json

# %%
search_results_df = pd.DataFrame(columns=columns)
try:
    for search_string in all_combinations:
        
        print(f"-------------- searching for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ------------")
        
        # Semantic Scholar
        # send http request to api
        sch_search_string = ' + '.join(f"'{term}'" for term in search_string)
        response_json = search_semantic_scholar(bulk=True, search_string=sch_search_string, year=sch_year)
        sch_results = response_json["data"]
        print(f">>> Semantic scholar total: {response_json['total']}")
        # Add results to DataFrame
        sch_count = 0
        if sch_results != 0:
            for result in sch_results:
                sch_count += 1
                paper_id = sch_get_paper_id(result)
                new_paper = {
                    'PaperTitle': result['title'],
                    'ID': paper_id,
                    'SearchString': sch_search_string,
                    'SearchedFrom': 'Semantic Scholar'
                }
                print(f"{sch_count}. sch process paper: ", new_paper)
                search_results_df = pd.concat([search_results_df, pd.DataFrame([new_paper])], ignore_index=True) 
        
        print(f"^^^^^^^^^^^^ searching end for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ^^^^^^^^^^^^^^^\n\n")
    search_results_df.to_csv('data/raw/search-results-sch.csv', index=False)
    print("XXXXXXXXXXXXXXXXXXXXXXXXXXXX search ends XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
except Exception as e:
    search_results_df.to_csv('data/raw/search-results-sch.csv', index=False)
    print(f"An error occurred: {e.with_traceback()}")
    print("XXXXXXXXXXXXXXXXXXXXXXXXXXXX search ends XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
# Out:
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'overreliance') (0/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'overreliance'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'overreliance') (0/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'over-reliance') (1/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'over-reliance'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'over-reliance') (1/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'misinformation') (2/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'misinformation'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 2
# 1. sch process paper:  {'PaperTitle': 'An investigation into the scientific landscape of the conversational and generative artificial intelligence, and human-chatbot interaction in education and research', 'ID': 'DOI:10.48550/arXiv.2407.12004', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'misinformation'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'Conversational and generative artificial intelligence and human–chatbot interaction in education and research', 'ID': 'DOI:10.1111/itor.13522', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'misinformation'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'misinformation') (2/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'accessibility') (3/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'accessibility'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 2
# 1. sch process paper:  {'PaperTitle': 'A Human-Centric Approach towards Equity and Inclusion in AI Education', 'ID': 'DOI:10.1609/aaaiss.v3i1.31264', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'accessibility'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'ChatGPT, artificial intelligence and scientific writing: What authors, peer reviewers and editors should know', 'ID': 'DOI:10.1177/14782715231181023', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'accessibility'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'accessibility') (3/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'privacy') (4/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'privacy'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 3
# 1. sch process paper:  {'PaperTitle': 'ChatGPT: How Can It Impact Nursing and Health Science Education?', 'ID': 'DOI:10.54133/ajms.v5i.209', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'privacy'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'An investigation into the scientific landscape of the conversational and generative artificial intelligence, and human-chatbot interaction in education and research', 'ID': 'DOI:10.48550/arXiv.2407.12004', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'privacy'", 'SearchedFrom': 'Semantic Scholar'}
# 3. sch process paper:  {'PaperTitle': 'Conversational and generative artificial intelligence and human–chatbot interaction in education and research', 'ID': 'DOI:10.1111/itor.13522', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'privacy'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'privacy') (4/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'environmental') (5/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'environmental'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'environmental') (5/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'explainability') (6/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'explainability'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 4
# 1. sch process paper:  {'PaperTitle': "ChatGPT's Capabilities for Use in Anatomy Education and Anatomy Research", 'ID': 'DOI:10.58600/eurjther1842', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'Error Correction and Adaptation in Conversational AI: A Review of Techniques and Applications in Chatbots', 'ID': 'DOI:10.3390/ai5020041', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 3. sch process paper:  {'PaperTitle': 'Lecture Notes: Introduction to Machine Learning for the Sciences', 'ID': 'paperid:b91c0756e13422d17e4c09e6e7f09ec1e4cd8aa5', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 4. sch process paper:  {'PaperTitle': 'An analysis of generative artificial intelligence tools usage to adapt and enrich software development courses', 'ID': 'DOI:10.36315/2024v1end123', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'explainability') (6/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'trustworthy') (7/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'trustworthy'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'trustworthy') (7/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'responsible') (8/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computing Education' + 'responsible'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 2
# 1. sch process paper:  {'PaperTitle': 'Assessing Learning of Computer Programming Skills in the Age of Generative Artificial Intelligence.', 'ID': 'DOI:10.1115/1.4064364', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'responsible'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'An analysis of generative artificial intelligence tools usage to adapt and enrich software development courses', 'ID': 'DOI:10.36315/2024v1end123', 'SearchString': "'Generative Artificial Intelligence' + 'Computing Education' + 'responsible'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'responsible') (8/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'overreliance') (9/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'overreliance'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 1
# 1. sch process paper:  {'PaperTitle': 'Surveying the Future of Computer and Data Science Education - Prospects and Pitfalls of Generative AI on Pedagogical Approaches', 'ID': 'DOI:10.5753/wei.2024.2103', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'overreliance'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'overreliance') (9/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'over-reliance') (10/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'over-reliance'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'over-reliance') (10/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'misinformation') (11/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'misinformation'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 3
# 1. sch process paper:  {'PaperTitle': 'Use of ChatGPT in Pediatric Urology and its Relevance in Clinical Practice: Is it useful?', 'ID': 'DOI:10.1101/2023.09.11.23295266', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'misinformation'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'An investigation into the scientific landscape of the conversational and generative artificial intelligence, and human-chatbot interaction in education and research', 'ID': 'DOI:10.48550/arXiv.2407.12004', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'misinformation'", 'SearchedFrom': 'Semantic Scholar'}
# 3. sch process paper:  {'PaperTitle': 'Conversational and generative artificial intelligence and human–chatbot interaction in education and research', 'ID': 'DOI:10.1111/itor.13522', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'misinformation'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'misinformation') (11/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'accessibility') (12/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'accessibility'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 3
# 1. sch process paper:  {'PaperTitle': 'A Human-Centric Approach towards Equity and Inclusion in AI Education', 'ID': 'DOI:10.1609/aaaiss.v3i1.31264', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'accessibility'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'ChatGPT and artificial intelligence the future of healthcare?', 'ID': 'DOI:10.3126/nmmj.v4i2.61892', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'accessibility'", 'SearchedFrom': 'Semantic Scholar'}
# 3. sch process paper:  {'PaperTitle': 'Human-Centered AI through Scalable Visual Data Analytics', 'ID': 'paperid:c6ce7fd941de2b1b9863cc8e43bc73a004343e52', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'accessibility'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'accessibility') (12/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'privacy') (13/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'privacy'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 3
# 1. sch process paper:  {'PaperTitle': 'AI’s 10 to Watch, 2022', 'ID': 'DOI:10.1109/MIS.2023.3252919', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'privacy'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'An investigation into the scientific landscape of the conversational and generative artificial intelligence, and human-chatbot interaction in education and research', 'ID': 'DOI:10.48550/arXiv.2407.12004', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'privacy'", 'SearchedFrom': 'Semantic Scholar'}
# 3. sch process paper:  {'PaperTitle': 'Conversational and generative artificial intelligence and human–chatbot interaction in education and research', 'ID': 'DOI:10.1111/itor.13522', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'privacy'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'privacy') (13/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'environmental') (14/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'environmental'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'environmental') (14/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'explainability') (15/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'explainability'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 7
# 1. sch process paper:  {'PaperTitle': 'Teaching CS50 with AI: Leveraging Generative Artificial Intelligence in Computer Science Education', 'ID': 'DOI:10.1145/3626252.3630938', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'Teaching CS50 with AI: Leveraging Generative Artificial Intelligence in Computer Science Education', 'ID': 'DOI:10.1145/3626253.3635427', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 3. sch process paper:  {'PaperTitle': "ChatGPT's Capabilities for Use in Anatomy Education and Anatomy Research", 'ID': 'DOI:10.58600/eurjther1842', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 4. sch process paper:  {'PaperTitle': 'Lecture Notes: Introduction to Machine Learning for the Sciences', 'ID': 'paperid:b91c0756e13422d17e4c09e6e7f09ec1e4cd8aa5', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 5. sch process paper:  {'PaperTitle': 'An analysis of generative artificial intelligence tools usage to adapt and enrich software development courses', 'ID': 'DOI:10.36315/2024v1end123', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 6. sch process paper:  {'PaperTitle': 'AI’s 10 to Watch, 2022', 'ID': 'DOI:10.1109/MIS.2023.3252919', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# 7. sch process paper:  {'PaperTitle': 'Using ChatGPT in Software Development Education', 'ID': 'DOI:10.1109/EDUCON60312.2024.10578808', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'explainability'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'explainability') (15/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'trustworthy') (16/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'trustworthy'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 2
# 1. sch process paper:  {'PaperTitle': 'When Geoscience Meets Generative AI and Large Language Models: Foundations, Trends, and Future Challenges', 'ID': 'DOI:10.48550/arXiv.2402.03349', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'trustworthy'", 'SearchedFrom': 'Semantic Scholar'}
# 2. sch process paper:  {'PaperTitle': 'AI’s 10 to Watch, 2022', 'ID': 'DOI:10.1109/MIS.2023.3252919', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'trustworthy'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'trustworthy') (16/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'responsible') (17/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'responsible'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 1
# 1. sch process paper:  {'PaperTitle': 'An analysis of generative artificial intelligence tools usage to adapt and enrich software development courses', 'ID': 'DOI:10.36315/2024v1end123', 'SearchString': "'Generative Artificial Intelligence' + 'Computer Science Education' + 'responsible'", 'SearchedFrom': 'Semantic Scholar'}
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'responsible') (17/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'overreliance') (18/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'overreliance'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'overreliance') (18/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'over-reliance') (19/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'over-reliance'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'over-reliance') (19/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'misinformation') (20/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'misinformation'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'misinformation') (20/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'accessibility') (21/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'accessibility'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'accessibility') (21/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'privacy') (22/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'privacy'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'privacy') (22/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'environmental') (23/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'environmental'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'environmental') (23/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'explainability') (24/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'explainability'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'explainability') (24/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'trustworthy') (25/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'trustworthy'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'trustworthy') (25/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CSEd', 'responsible') (26/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CSEd' + 'responsible'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CSEd', 'responsible') (26/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CER', 'overreliance') (27/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CER' + 'overreliance'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CER', 'overreliance') (27/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CER', 'over-reliance') (28/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CER' + 'over-reliance'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CER', 'over-reliance') (28/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CER', 'misinformation') (29/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CER' + 'misinformation'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CER', 'misinformation') (29/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CER', 'accessibility') (30/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CER' + 'accessibility'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CER', 'accessibility') (30/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CER', 'privacy') (31/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CER' + 'privacy'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CER', 'privacy') (31/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CER', 'environmental') (32/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CER' + 'environmental'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# >>> Semantic scholar total: 0
# ^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'CER', 'environmental') (32/576) ^^^^^^^^^^^^^^^
#
#
# -------------- searching for ('Generative Artificial Intelligence', 'CER', 'explainability') (33/576) ------------
# headers: {'Content-Type': 'application/json', 'x-api-key': 'X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5'}
# params: {'query': "'Generative Artificial Intelligence' + 'CER' + 'explainability'", 'year': '2017-', 'fields': 'title,externalIds,paperId,url,authors'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       7 # Semantic Scholar
#       8 # send http request to api
#       9 sch_search_string = ' + '.join(f"'{term}'" for term in search_string)
# ---> 10 response_json = search_semantic_scholar(bulk=True, search_string=sch_search_string, year=sch_year)
#      11 sch_results = response_json["data"]
#      12 print(f">>> Semantic scholar total: {response_json['total']}")
#
# Cell In[8], line 38, in search_semantic_scholar(bulk, search_string, fields, year)
#      36 print("headers:", headers)
#      37 print("params:", params)
# ---> 38 response = requests.get(api_url, headers=headers, params=params)
#      39 while response.status_code != 200:
#      40     print(f"Semantic Scholar response status code: {response.status_code}, waiting 30 seconds...")
#
# File ~/projects/publication_scraper/.venv/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/projects/publication_scraper/.venv/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/projects/publication_scraper/.venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/projects/publication_scraper/.venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/projects/publication_scraper/.venv/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/projects/publication_scraper/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/projects/publication_scraper/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/projects/publication_scraper/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Web of Science
all_search_results_df = pd.DataFrame()

def get_wos_search_string(keywords):
    search_string = ""
    for keyword in keywords:
        search_string += f'"{keyword}" '
    return search_string

def search_web_of_science(wos_search_string, year_start=2017, year_end=2023):
    def fetch_data(start_record):
        url = 'https://api.clarivate.com/api/wos'
        params = {
            # https://webofscience.help.clarivate.com/en-us/Content/wos-core-collection/woscc-search-field-tags.htm
            'usrQuery': f'(TS=({wos_search_string})) AND PY=({year_start}-{year_end})',
            'count': 100,
            'firstRecord': start_record,
            'databaseId': 'WOS',
            'links': "false",
        }
        headers = {
            'X-ApiKey': '1c19a6c1114c4ee6f84142bba8040e6bbaa9825b',
            "Content-Type": "application/json"
        }

        try:
            response = requests.get(url, headers=headers, params=params)
            response.raise_for_status()  # Raises an HTTPError for certain status codes
            return response.json()
        except HTTPError as http_err:
            if response.status_code == 429:
                print("Rate limit reached, waiting 30s to retry...")
                time.sleep(30)  # Adjust the sleep time as necessary
                return fetch_data(start_record)  # Retry the request
            else:
                print(f"HTTP error occurred: {http_err}")
                return None
        except Exception as err:
            print(f"Other error occurred: {err}")
            return None

    start_record = 1
    total_records = None
    paper_count = 0
    search_results = []

    while True:
        data = fetch_data(start_record)
        if data.get("QueryResult").get("RecordsFound") == 0 or data is None:
            total_records = 0
            break

        if total_records is None:
            total_records = data['QueryResult']['RecordsFound']

        records = data['Data']['Records']['records']['REC']
        for record in records:
            uid = record['UID']
            for identifier in record['dynamic_data']['cluster_related']['identifiers']['identifier']:
                if isinstance(identifier, dict) and identifier['type'] == 'doi':
                    uid = f"DOI:{identifier['value']}"
                    break
            titles = record['static_data']['summary']['titles']['title']
            title = next((t['content'] for t in titles if t['type'] == 'item'), 'No title found')
            search_results.append({
                'PaperTitle': title,
                'ID': uid,
                'SearchString': wos_search_string,
                'SearchedFrom': 'Web of Science'
            })
        paper_count += len(records)
        start_record += len(records)

        if paper_count >= total_records:
            break

    return {
        'total': total_records,
        'data': search_results
    }


try:
    for idx, combination in enumerate(all_combinations):
        # https://webofscience.help.clarivate.com/en-us/Content/search-operators.html
        wos_search_string = get_wos_search_string(combination)
        print(
            f"------------ Searching Web of Science for: {wos_search_string} ({idx + 1}/{len(all_combinations)}) -----------")

        response_json = search_web_of_science(wos_search_string=wos_search_string)
        wos_results = response_json['data']
        total_results = response_json['total']
        print(f">>> Web of Science total: {total_results}")

        # Add results to DataFrame
        if wos_results:
            search_results_df = pd.DataFrame(wos_results)
            all_search_results_df = pd.concat([all_search_results_df, search_results_df], ignore_index=True)
            print(search_results_df)
        time.sleep(0.5)
        print(
            f"^^^^^^^^^^^^^ Search end for: {wos_search_string} ({idx + 1}/{len(all_combinations)}) ^^^^^^^^^^^^^^^^\n\n")

    # Save the complete DataFrame to a CSV file
    all_search_results_df.to_csv('data/raw/search-results-web-of-science.csv', index=False)
    print(
        "XXXXXXXXXXXXXXXXXXXXXXXXXXXX Search ends. Results saved to 'search-results-web-of-science.csv' XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
except Exception as e:
    print(f"Error occurred: {e.with_traceback()}")
    all_search_results_df.to_csv('data/raw/search-results-web-of-science.csv', index=False)
# Out:
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "overreliance"  (1/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "overreliance"  (1/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "over-reliance"  (2/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "over-reliance"  (2/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "misinformation"  (3/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "misinformation"  (3/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "accessibility"  (4/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "accessibility"  (4/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "privacy"  (5/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "privacy"  (5/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "environmental"  (6/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "environmental"  (6/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "explainability"  (7/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "explainability"  (7/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "trustworthy"  (8/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "trustworthy"  (8/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computing Education" "responsible"  (9/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computing Education" "responsible"  (9/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "overreliance"  (10/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "overreliance"  (10/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "over-reliance"  (11/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "over-reliance"  (11/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "misinformation"  (12/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "misinformation"  (12/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "accessibility"  (13/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "accessibility"  (13/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "privacy"  (14/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "privacy"  (14/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "environmental"  (15/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "environmental"  (15/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "explainability"  (16/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "explainability"  (16/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "trustworthy"  (17/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "trustworthy"  (17/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "Computer Science Education" "responsible"  (18/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "Computer Science Education" "responsible"  (18/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "overreliance"  (19/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "overreliance"  (19/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "over-reliance"  (20/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "over-reliance"  (20/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "misinformation"  (21/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "misinformation"  (21/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "accessibility"  (22/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "accessibility"  (22/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "privacy"  (23/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "privacy"  (23/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "environmental"  (24/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "environmental"  (24/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "explainability"  (25/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "explainability"  (25/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "trustworthy"  (26/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "trustworthy"  (26/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CSEd" "responsible"  (27/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CSEd" "responsible"  (27/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "overreliance"  (28/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "overreliance"  (28/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "over-reliance"  (29/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "over-reliance"  (29/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "misinformation"  (30/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "misinformation"  (30/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "accessibility"  (31/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "accessibility"  (31/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "privacy"  (32/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "privacy"  (32/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "environmental"  (33/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "environmental"  (33/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "explainability"  (34/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "explainability"  (34/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "trustworthy"  (35/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "trustworthy"  (35/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative Artificial Intelligence" "CER" "responsible"  (36/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative Artificial Intelligence" "CER" "responsible"  (36/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "overreliance"  (37/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "overreliance"  (37/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "over-reliance"  (38/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "over-reliance"  (38/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "misinformation"  (39/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "misinformation"  (39/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "accessibility"  (40/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "accessibility"  (40/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "privacy"  (41/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "privacy"  (41/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "environmental"  (42/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "environmental"  (42/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "explainability"  (43/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "explainability"  (43/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "trustworthy"  (44/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "trustworthy"  (44/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computing Education" "responsible"  (45/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computing Education" "responsible"  (45/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "overreliance"  (46/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "overreliance"  (46/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "over-reliance"  (47/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "over-reliance"  (47/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "misinformation"  (48/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "misinformation"  (48/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "accessibility"  (49/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "accessibility"  (49/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "privacy"  (50/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "privacy"  (50/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "environmental"  (51/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "environmental"  (51/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "explainability"  (52/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "explainability"  (52/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "trustworthy"  (53/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "trustworthy"  (53/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "Computer Science Education" "responsible"  (54/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "Computer Science Education" "responsible"  (54/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "overreliance"  (55/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "overreliance"  (55/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "over-reliance"  (56/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "over-reliance"  (56/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "misinformation"  (57/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "misinformation"  (57/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "accessibility"  (58/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "accessibility"  (58/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "privacy"  (59/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "privacy"  (59/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "environmental"  (60/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "environmental"  (60/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "explainability"  (61/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "explainability"  (61/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "trustworthy"  (62/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "trustworthy"  (62/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CSEd" "responsible"  (63/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CSEd" "responsible"  (63/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "overreliance"  (64/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "overreliance"  (64/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "over-reliance"  (65/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "over-reliance"  (65/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "misinformation"  (66/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "misinformation"  (66/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "accessibility"  (67/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "accessibility"  (67/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "privacy"  (68/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "privacy"  (68/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "environmental"  (69/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "environmental"  (69/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "explainability"  (70/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "explainability"  (70/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "trustworthy"  (71/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "trustworthy"  (71/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Generative AI" "CER" "responsible"  (72/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Generative AI" "CER" "responsible"  (72/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "overreliance"  (73/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "overreliance"  (73/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "over-reliance"  (74/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "over-reliance"  (74/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "misinformation"  (75/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "misinformation"  (75/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "accessibility"  (76/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "accessibility"  (76/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "privacy"  (77/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "privacy"  (77/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "environmental"  (78/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "environmental"  (78/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "explainability"  (79/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "explainability"  (79/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "trustworthy"  (80/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "trustworthy"  (80/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computing Education" "responsible"  (81/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computing Education" "responsible"  (81/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "overreliance"  (82/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "overreliance"  (82/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "over-reliance"  (83/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "over-reliance"  (83/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "misinformation"  (84/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "misinformation"  (84/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "accessibility"  (85/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "accessibility"  (85/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "privacy"  (86/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "privacy"  (86/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "environmental"  (87/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "environmental"  (87/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "explainability"  (88/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "explainability"  (88/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "trustworthy"  (89/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "trustworthy"  (89/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "Computer Science Education" "responsible"  (90/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "Computer Science Education" "responsible"  (90/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "overreliance"  (91/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "overreliance"  (91/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "over-reliance"  (92/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "over-reliance"  (92/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "misinformation"  (93/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "misinformation"  (93/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "accessibility"  (94/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "accessibility"  (94/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "privacy"  (95/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "privacy"  (95/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "environmental"  (96/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "environmental"  (96/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "explainability"  (97/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "explainability"  (97/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "trustworthy"  (98/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "trustworthy"  (98/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CSEd" "responsible"  (99/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CSEd" "responsible"  (99/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "overreliance"  (100/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "overreliance"  (100/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "over-reliance"  (101/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "over-reliance"  (101/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "misinformation"  (102/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "misinformation"  (102/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "accessibility"  (103/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "accessibility"  (103/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "privacy"  (104/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "privacy"  (104/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "environmental"  (105/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "environmental"  (105/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "explainability"  (106/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "explainability"  (106/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "trustworthy"  (107/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "trustworthy"  (107/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "GenAI" "CER" "responsible"  (108/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "GenAI" "CER" "responsible"  (108/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "overreliance"  (109/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "overreliance"  (109/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "over-reliance"  (110/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "over-reliance"  (110/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "misinformation"  (111/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "misinformation"  (111/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "accessibility"  (112/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "accessibility"  (112/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "privacy"  (113/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "privacy"  (113/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "environmental"  (114/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "environmental"  (114/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "explainability"  (115/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "explainability"  (115/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "trustworthy"  (116/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "trustworthy"  (116/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computing Education" "responsible"  (117/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computing Education" "responsible"  (117/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "overreliance"  (118/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "overreliance"  (118/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "over-reliance"  (119/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "over-reliance"  (119/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "misinformation"  (120/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "misinformation"  (120/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "accessibility"  (121/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "accessibility"  (121/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "privacy"  (122/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "privacy"  (122/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "environmental"  (123/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "environmental"  (123/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "explainability"  (124/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "explainability"  (124/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "trustworthy"  (125/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "trustworthy"  (125/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "Computer Science Education" "responsible"  (126/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "Computer Science Education" "responsible"  (126/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "overreliance"  (127/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "overreliance"  (127/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "over-reliance"  (128/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "over-reliance"  (128/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "misinformation"  (129/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "misinformation"  (129/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "accessibility"  (130/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "accessibility"  (130/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "privacy"  (131/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "privacy"  (131/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "environmental"  (132/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "environmental"  (132/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "explainability"  (133/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "explainability"  (133/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "trustworthy"  (134/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "trustworthy"  (134/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CSEd" "responsible"  (135/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CSEd" "responsible"  (135/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "overreliance"  (136/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "overreliance"  (136/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "over-reliance"  (137/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "over-reliance"  (137/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "misinformation"  (138/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "misinformation"  (138/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "accessibility"  (139/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "accessibility"  (139/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "privacy"  (140/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "privacy"  (140/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "environmental"  (141/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "environmental"  (141/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "explainability"  (142/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "explainability"  (142/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "trustworthy"  (143/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "trustworthy"  (143/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "Gen AI" "CER" "responsible"  (144/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "Gen AI" "CER" "responsible"  (144/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "overreliance"  (145/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "overreliance"  (145/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "over-reliance"  (146/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "over-reliance"  (146/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "misinformation"  (147/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "misinformation"  (147/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "accessibility"  (148/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "accessibility"  (148/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "privacy"  (149/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "privacy"  (149/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "environmental"  (150/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "environmental"  (150/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "explainability"  (151/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "explainability"  (151/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "trustworthy"  (152/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "trustworthy"  (152/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computing Education" "responsible"  (153/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computing Education" "responsible"  (153/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "overreliance"  (154/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "overreliance"  (154/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "over-reliance"  (155/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "over-reliance"  (155/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "misinformation"  (156/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "misinformation"  (156/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "accessibility"  (157/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "accessibility"  (157/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "privacy"  (158/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "privacy"  (158/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "environmental"  (159/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "environmental"  (159/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "explainability"  (160/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "explainability"  (160/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "trustworthy"  (161/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "trustworthy"  (161/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "Computer Science Education" "responsible"  (162/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "Computer Science Education" "responsible"  (162/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "overreliance"  (163/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "overreliance"  (163/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "over-reliance"  (164/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "over-reliance"  (164/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "misinformation"  (165/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "misinformation"  (165/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "accessibility"  (166/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "accessibility"  (166/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "privacy"  (167/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "privacy"  (167/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "environmental"  (168/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "environmental"  (168/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "explainability"  (169/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "explainability"  (169/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "trustworthy"  (170/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "trustworthy"  (170/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CSEd" "responsible"  (171/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CSEd" "responsible"  (171/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "overreliance"  (172/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "overreliance"  (172/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "over-reliance"  (173/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "over-reliance"  (173/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "misinformation"  (174/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "misinformation"  (174/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "accessibility"  (175/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "accessibility"  (175/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "privacy"  (176/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "privacy"  (176/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "environmental"  (177/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "environmental"  (177/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "explainability"  (178/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "explainability"  (178/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "trustworthy"  (179/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "trustworthy"  (179/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LLM" "CER" "responsible"  (180/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LLM" "CER" "responsible"  (180/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "overreliance"  (181/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "overreliance"  (181/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "over-reliance"  (182/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "over-reliance"  (182/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "misinformation"  (183/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "misinformation"  (183/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "accessibility"  (184/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "accessibility"  (184/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "privacy"  (185/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "privacy"  (185/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "environmental"  (186/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "environmental"  (186/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "explainability"  (187/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "explainability"  (187/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "trustworthy"  (188/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "trustworthy"  (188/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computing Education" "responsible"  (189/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computing Education" "responsible"  (189/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computer Science Education" "overreliance"  (190/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computer Science Education" "overreliance"  (190/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computer Science Education" "over-reliance"  (191/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computer Science Education" "over-reliance"  (191/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computer Science Education" "misinformation"  (192/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computer Science Education" "misinformation"  (192/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computer Science Education" "accessibility"  (193/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computer Science Education" "accessibility"  (193/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computer Science Education" "privacy"  (194/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computer Science Education" "privacy"  (194/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computer Science Education" "environmental"  (195/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "LM" "Computer Science Education" "environmental"  (195/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "LM" "Computer Science Education" "explainability"  (196/576) -----------
# >>> Web of Science total: 0
# ...
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "Computer Science Education" "over-reliance"  (515/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "Computer Science Education" "misinformation"  (516/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "Computer Science Education" "misinformation"  (516/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "Computer Science Education" "accessibility"  (517/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "Computer Science Education" "accessibility"  (517/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "Computer Science Education" "privacy"  (518/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "Computer Science Education" "privacy"  (518/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "Computer Science Education" "environmental"  (519/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "Computer Science Education" "environmental"  (519/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "Computer Science Education" "explainability"  (520/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "Computer Science Education" "explainability"  (520/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "Computer Science Education" "trustworthy"  (521/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "Computer Science Education" "trustworthy"  (521/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "Computer Science Education" "responsible"  (522/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "Computer Science Education" "responsible"  (522/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "overreliance"  (523/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "overreliance"  (523/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "over-reliance"  (524/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "over-reliance"  (524/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "misinformation"  (525/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "misinformation"  (525/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "accessibility"  (526/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "accessibility"  (526/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "privacy"  (527/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "privacy"  (527/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "environmental"  (528/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "environmental"  (528/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "explainability"  (529/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "explainability"  (529/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "trustworthy"  (530/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "trustworthy"  (530/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CSEd" "responsible"  (531/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CSEd" "responsible"  (531/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "overreliance"  (532/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "overreliance"  (532/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "over-reliance"  (533/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "over-reliance"  (533/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "misinformation"  (534/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "misinformation"  (534/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "accessibility"  (535/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "accessibility"  (535/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "privacy"  (536/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "privacy"  (536/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "environmental"  (537/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "environmental"  (537/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "explainability"  (538/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "explainability"  (538/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "trustworthy"  (539/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "trustworthy"  (539/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "compact language model" "CER" "responsible"  (540/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "compact language model" "CER" "responsible"  (540/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "overreliance"  (541/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "overreliance"  (541/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "over-reliance"  (542/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "over-reliance"  (542/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "misinformation"  (543/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "misinformation"  (543/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "accessibility"  (544/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "accessibility"  (544/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "privacy"  (545/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "privacy"  (545/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "environmental"  (546/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "environmental"  (546/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "explainability"  (547/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "explainability"  (547/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "trustworthy"  (548/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "trustworthy"  (548/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computing Education" "responsible"  (549/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computing Education" "responsible"  (549/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "overreliance"  (550/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "overreliance"  (550/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "over-reliance"  (551/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "over-reliance"  (551/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "misinformation"  (552/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "misinformation"  (552/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "accessibility"  (553/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "accessibility"  (553/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "privacy"  (554/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "privacy"  (554/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "environmental"  (555/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "environmental"  (555/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "explainability"  (556/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "explainability"  (556/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "trustworthy"  (557/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "trustworthy"  (557/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "Computer Science Education" "responsible"  (558/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "Computer Science Education" "responsible"  (558/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "overreliance"  (559/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "overreliance"  (559/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "over-reliance"  (560/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "over-reliance"  (560/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "misinformation"  (561/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "misinformation"  (561/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "accessibility"  (562/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "accessibility"  (562/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "privacy"  (563/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "privacy"  (563/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "environmental"  (564/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "environmental"  (564/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "explainability"  (565/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "explainability"  (565/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "trustworthy"  (566/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "trustworthy"  (566/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CSEd" "responsible"  (567/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CSEd" "responsible"  (567/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "overreliance"  (568/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "overreliance"  (568/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "over-reliance"  (569/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "over-reliance"  (569/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "misinformation"  (570/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "misinformation"  (570/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "accessibility"  (571/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "accessibility"  (571/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "privacy"  (572/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "privacy"  (572/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "environmental"  (573/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "environmental"  (573/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "explainability"  (574/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "explainability"  (574/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "trustworthy"  (575/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "trustworthy"  (575/576) ^^^^^^^^^^^^^^^^
#
#
# ------------ Searching Web of Science for: "foundation model" "CER" "responsible"  (576/576) -----------
# >>> Web of Science total: 0
# ^^^^^^^^^^^^^ Search end for: "foundation model" "CER" "responsible"  (576/576) ^^^^^^^^^^^^^^^^
#
#
# XXXXXXXXXXXXXXXXXXXXXXXXXXXX Search ends. Results saved to 'search-results-web-of-science.csv' XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
# dblp WITH tertiary level keywords:  # TODO: it is expected that crossref don't have much result with tertiary keywords included
def get_dblp_search_string(keywords):
    search_string = ""
    for keyword in keywords:
        search_string += f'"{keyword}"$ '
    return search_string


search_results_df = pd.DataFrame(columns=columns)
try:
    for search_string in all_combinations:

        print(f"------------------------------- searching for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ------------------------------")
        # search in dblp
        dblp_search_string = get_dblp_search_string(search_string)
        dblp_search_results = dblp.search(dblp_search_string + dblp_formatted_years)
        if dblp_search_results is None:
            print(f">>> DBLP total: 0")
        else:
            print(f">>> DBLP total: {len(dblp_search_results)}")
            dblp_count = 0
            for key, result in dblp_search_results.items():
                dblp_count += 1
                if result.get('info').get('doi') is None:
                    paper_id = "url:" + result.get("info").get("url")
                else:
                    paper_id = "DOI:" + result.get('info').get('doi')
                new_paper = {
                    'PaperTitle': result.get('info').get('title'),
                    'ID': paper_id,
                    'SearchString': dblp_search_string,
                    'SearchedFrom': 'DBLP'
                }
                print(f"{dblp_count}. DBLP process paper: ", new_paper)
                search_results_df = pd.concat([search_results_df, pd.DataFrame([new_paper])], ignore_index=True)
        time.sleep(10)
        print(f"^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n\n")
    search_results_df.to_csv('data/raw/search-results-dblp.csv', index=False)
    print("XXXXXXXXXXXXXXXXXXXXXXXXXXXX search ends XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
except Exception as e:
    search_results_df.to_csv('data/raw/search-results-dblp.csv', index=False)
    print(f"An error occurred: {e.with_traceback()}")
    print("XXXXXXXXXXXXXXXXXXXXXXXXXXXX search ends XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
# Out:
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'overreliance') (0/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'overreliance') (0/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'over-reliance') (1/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'over-reliance') (1/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'misinformation') (2/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'misinformation') (2/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'accessibility') (3/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'accessibility') (3/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'privacy') (4/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'privacy') (4/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'environmental') (5/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'environmental') (5/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'explainability') (6/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'explainability') (6/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'trustworthy') (7/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'trustworthy') (7/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'responsible') (8/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computing Education', 'responsible') (8/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'overreliance') (9/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'overreliance') (9/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'over-reliance') (10/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'over-reliance') (10/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'misinformation') (11/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'misinformation') (11/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'accessibility') (12/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'accessibility') (12/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'privacy') (13/576) ------------------------------
# >>> DBLP total: 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for ('Generative Artificial Intelligence', 'Computer Science Education', 'privacy') (13/576) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# ------------------------------- searching for ('Generative Artificial Intelligence', 'Computer Science Education', 'environmental') (14/576) ------------------------------
# >>> DBLP total: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 36
#      34             print(f"{dblp_count}. DBLP process paper: ", new_paper)
#      35             search_results_df = pd.concat([search_results_df, pd.DataFrame([new_paper])], ignore_index=True)
# ---> 36     time.sleep(10)
#      37     print(f"^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n\n")
#      38 search_results_df.to_csv('data/raw/search-results-dblp.csv', index=False)
#
# KeyboardInterrupt:

# %%
#TODO: NOTE: Please don't use crossref to perform actual search
# import time
# crossref_work = Works()
# search_results_df = pd.DataFrame(columns=columns)
# try:
#     for search_string in all_combinations:
# 
#         print(f"------------- searching for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ---------------")
# 
#         # Crossref
#         # only take first 10
#         crossref_search_string = ' '.join(search_string)
#         cr_search_results = crossref_work.query(crossref_search_string).filter(from_online_pub_date=crossref_year)
#         print(f"Crossref total: {cr_search_results.count()}")
#         crossref_count = 0
#         for cr_result in cr_search_results:
#             crossref_count += 1
#             new_paper = {
#                 'PaperTitle': cr_result.get('title'),
#                 'DOI': cr_result.get('DOI'),
#                 'SearchString': crossref_search_string,
#                 'SearchedFrom': 'Crossref'
#             }
#             print(f"{crossref_count}. Crossref process paper: ", new_paper)
#             search_results_df = pd.concat([search_results_df, pd.DataFrame([new_paper])], ignore_index=True)
# 
#             if crossref_count == 10:
#                 break
#         print(f"^^^^^^^^^^^^ searching end for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ^^^^^^^^^^^^^^^^^^\n\n")
#     search_results_df.to_csv('data/raw/search-results-sch.csv', index=False)
#     print("XXXXXXXXXXXXXXXXXXXXXXXXXXXX search ends XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
# except Exception as e:
#     search_results_df.to_csv('data/raw/search-results-sch.csv', index=False)
#     print(f"An error occurred: {e.with_traceback()}")
#     print("XXXXXXXXXXXXXXXXXXXXXXXXXXXX search ends XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
# Out:
# ------------- searching for ('Generative Artificial Intelligence', 'Computing Education', 'overreliance') (0/576) ---------------
# Crossref total: 1703122
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 15
#      13 print(f"Crossref total: {cr_search_results.count()}")
#      14 crossref_count = 0
# ---> 15 for cr_result in cr_search_results:
#      16     crossref_count += 1
#      17     new_paper = {
#      18         'PaperTitle': cr_result.get('title'),
#      19         'DOI': cr_result.get('DOI'),
#      20         'SearchString': crossref_search_string,
#      21         'SearchedFrom': 'Crossref'
#      22     }
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/crossref/restful.py:310, in Endpoint.__iter__(self)
#     308 request_params["rows"] = LIMIT
#     309 while True:
# --> 310     result = self.do_http_request(
#     311         "get",
#     312         request_url,
#     313         data=request_params,
#     314         custom_header=self.custom_header,
#     315         timeout=self.timeout,
#     316     )
#     318     if result.status_code == 404:
#     319         return
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/crossref/restful.py:78, in HTTPRequest.do_http_request(self, method, endpoint, data, files, timeout, only_headers, custom_header)
#      76     result = action(endpoint, data=data, files=files, timeout=timeout, headers=headers)
#      77 else:
# ---> 78     result = action(endpoint, params=data, timeout=timeout, headers=headers)
#      80 if self.throttle is True:
#      81     self._update_rate_limits(result.headers)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# TODO: NOTE: Please don't use serpapi (Google Scholar) to perform actual search

# from urllib.parse import parse_qs, urlparse
# import time
# # Google scholar 
# from serpapi import GoogleSearch
# 
# 
# 
# params = {
#     "engine": "google_scholar",
#     "q": "",
#     "as_ylo": start_year,
#     "api_key": "c029b25c27cf0b387830ed99a0976387fb3f382c068a2f995b0bb92a55c7bb0f"
# }
# search_results_df = pd.DataFrame(columns=columns)
# 
# 
# 
# def gscholar_get_paper_id(gscholar_result):
#     paper_title = gscholar_result.get("title")
#     have_author = gscholar_result.get("publication_info").get("authors")
#     if have_author:
#         paper_author1 = gscholar_result.get("publication_info").get("authors")[0].get("name")
#         paper_author1_last_name = paper_author1.split(" ")[-1]
#     else:
#         paper_author1_last_name, paper_author1 = "", ""
#     search_string = f"{paper_author1} {paper_title}"
#     try:
#         sch_results = search_semantic_scholar(bulk=False, search_string=search_string, year=sch_year)
#     except Exception as e:
#         print(f"An error occurred: {e}")
#         return None
#     if sch_results.get("total") == 0:
#         return f"url:{gscholar_result.get('link')}"
#     sch_paper = sch_results.get("data")[0]
#     sch_paper_authors = sch_paper.get("authors", [])
#     if sch_paper_authors:
#         first_sch_author_last_name = sch_paper_authors[0].get("name").split(" ")[-1] if sch_paper_authors[0].get("name") else ""
#     else:
#         first_sch_author_last_name = ""
# 
#     # Compare authors if available, otherwise compare titles only
#     if ((not have_author or paper_author1_last_name == first_sch_author_last_name) and 
#             sch_paper["title"].lower() == paper_title.lower()):
#         return sch_get_paper_id(sch_paper)
#     else:
#         return f"url:{gscholar_result.get('link')}"
# 
# 
# 
# try:
#     for search_string in all_combinations:
#         start_num = 0  # Initialize start_num for each search string
#         while True:
#             print(f"------- Fetching results starting from {start_num} for {search_string} -------")
#             gscholar_search_string = '"Generative AI" AND overreliance AND mitigation'
#             params["q"] = gscholar_search_string
#             params["start"] = start_num  # Set start parameter for pagination
# 
#             search = GoogleSearch(params)
#             gscholar_search_results = search.get_dict()
#             if gscholar_search_results.get("error"):
#                 print(f">>> {gscholar_search_results.get('error')}")
#                 break
#             else:
#                 print(f">>> Google Scholar total: {gscholar_search_results.get('search_information').get('total_results')}")
#                 gscholar_count = 0
#                 for gscholar_result in gscholar_search_results.get("organic_results"):
#                     gscholar_count += 1
#                     gscholar_paper_id = gscholar_get_paper_id(gscholar_result)
#                     new_paper = {
#                         'PaperTitle': gscholar_result.get('title'),
#                         'PaperId': gscholar_paper_id,
#                         'SearchString': gscholar_search_string,
#                         'SearchedFrom': 'Google Scholar'
#                     }
#                     print(f"{start_num + gscholar_count}. Google Scholar process paper: ", new_paper)
#                     search_results_df = pd.concat([search_results_df, pd.DataFrame([new_paper])], ignore_index=True)
# 
#                     # Check if we reached 10 results on the current page
#                     if gscholar_count == 10:
#                         break
# 
#                 serpapi_pagination = gscholar_search_results.get("serpapi_pagination")
#                 if serpapi_pagination and "next" in serpapi_pagination:
#                     next_link = serpapi_pagination["next"]
#                     next_start = parse_qs(urlparse(next_link).query).get("start")
#                     if next_start:
#                         start_num = int(next_start[0])
#                     else:
#                         print(f"^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n\n")
#                         break  # Break if next_start is not available
#                 else:
#                     print(f"^^^^^^^^^^^^^^^^^^^^^^^^^^^ searching end for {search_string} ({all_combinations.index(search_string)}/{len(all_combinations)}) ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n\n")
#                     break  # Break if there is no 'next' link
# 
# 
#     search_results_df.to_csv('data/raw/search-results-gscholar.csv', index=False)
#     print("XXXXXXXXXXXXXXXXXXXXXXXXXXXX search ends XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
# except Exception as e:
#     search_results_df.to_csv('data/raw/search-results-gscholar.csv', index=False)
#     print(f"An error occurred: {e.with_traceback()}")
#     print("XXXXXXXXXXXXXXXXXXXXXXXXXXXX search ends XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")

# %%
# remove duplicates internally
sch_search_results_df = pd.read_csv('data/raw/search-results-sch.csv')
dblp_search_results_df = pd.read_csv('data/raw/search-results-dblp.csv')
wos_search_results_df = pd.read_csv('data/raw/search-results-web-of-science.csv')

# First, remove duplicates based on the 'ID'
sch_search_results_df = sch_search_results_df.drop_duplicates(subset=['ID'])
dblp_search_results_df = dblp_search_results_df.drop_duplicates(subset=['ID'])
wos_search_results_df = wos_search_results_df.drop_duplicates(subset=['ID'])

# Next, remove duplicates based on the 'PaperTitle'
sch_search_results_df = sch_search_results_df.drop_duplicates(subset=['PaperTitle'])
dblp_search_results_df = dblp_search_results_df.drop_duplicates(subset=['PaperTitle'])
wos_search_results_df = wos_search_results_df.drop_duplicates(subset=['PaperTitle'])


sch_search_results_df.to_csv('data/cleaned/search-results-sch-cleaned.csv', index=False)
dblp_search_results_df.to_csv('data/cleaned/search-results-dblp-cleaned.csv', index=False)
wos_search_results_df.to_csv('data/cleaned/search-results-web-of-science-cleaned.csv', index=False)

# %%
sch_search_results_df = pd.read_csv('data/cleaned/search-results-sch-cleaned.csv')
dblp_search_results_df = pd.read_csv('data/cleaned/search-results-dblp-cleaned.csv')
wos_search_results_df = pd.read_csv('data/cleaned/search-results-web-of-science-cleaned.csv')

# Concatenate dataframes
frames = [sch_search_results_df, dblp_search_results_df, wos_search_results_df]

master_df = pd.concat(frames, axis=0, ignore_index=True)

# Drop duplicates based on ID column to avoid duplicate rows for the same ID
master_df.drop_duplicates(subset='ID', keep='first', inplace=True)

# Save to CSV
master_df.to_csv('data/cleaned/search-results-master.csv', index=False)

# %%
# clean up master dfs by removing papers that contain keywords in title
edu_master_df = pd.read_csv('data/cleaned/edu/search-results-master.csv')
social_master_df = pd.read_csv('data/cleaned/social/search-results-master.csv')

KEYWORDS = ["oil", "tree", "forest", "agriculture", "soil", "palms", "crop", "wildlife"] # Add more keywords as needed
keywords_regex = r'\b(?:' + '|'.join(KEYWORDS) + r')\b'

# Cleaning dataframes
edu_master_df_cleaned = edu_master_df[
    ~edu_master_df['PaperTitle'].str.contains(keywords_regex, case=False, regex=True)]
social_master_df_cleaned = social_master_df[
    ~social_master_df['PaperTitle'].str.contains(keywords_regex, case=False, regex=True)]

# Saving the cleaned dataframes
edu_master_df_cleaned.to_csv('data/cleaned/edu/search-results-master-v3.csv', index=False)
social_master_df_cleaned.to_csv('data/cleaned/social/search-results-master-v3.csv', index=False)
