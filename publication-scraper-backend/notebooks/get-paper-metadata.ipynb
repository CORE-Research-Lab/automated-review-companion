# %%
import os
import pandas as pd
import numpy as np
import dblp
from crossref.restful import Works
import requests
from serpapi import GoogleSearch

# %%
crossref_work = Works()

# %%
raw_dfs = [
    "data/cleaned/social/search-results-master-v3.csv",
]

# %%
# Prepare DataFrame to store the results
columns = [
    "PaperTitle",
    "DOI",
    "Authors",
    "Abstract",
    "Publisher",
    "SemanticScholarUrl",
    "DoiUrl",
    "PublicationDate",
    "FieldOfStudy",
    "Conference-Journal",
    "PublicationTypes",
    "SearchString",
    "CitationCount",
    "SearchedFrom",
]

# %%
sch_fields = [
    "title",
    "externalIds",
    "authors",
    "abstract",
    "url",
    "publicationDate",
    "fieldsOfStudy",
    "venue",
    "publicationTypes",
    "citationCount",
    "externalIds",
]

# %%
# Helpers
def extract_sch(api_url, sch_fields):
    headers = {"Content-Type": "application/json"}
    params = {
        "fields": ",".join(sch_fields),
    }
    try:
        response = requests.get(api_url, headers=headers, params=params)
        result = response.json()
        return result
    except Exception as e:
        print(e)
        return {"error": e}


def get_affiliations_google_scholar(author_name) -> list[str]:
    params = {
        "engine": "google_scholar_profiles",
        "mauthors": author_name.strip(),
        "api_key": os.environ.get("GOOGLE_SCHOLAR_API_KEY"),
    }

    try:
        search = GoogleSearch(params)
        results = search.get_dict()
        if (
            results.get("search_metadata", {}).get("status") == "Error"
            or len(results.get("profiles", [])) == 0
        ):
            return ["No Affiliation"]
        else:
            return [results["profiles"][0]["affiliations"]]
    except Exception as e:
        print(e)
        return ["No Affiliation"]


def extract_authors(sch_paper, crossref_paper):
    authors = None
    if crossref_paper is not None:
        authors = crossref_paper.get("author")
    if authors is not None:
        for i in range(len(authors)):
            author = authors[i]
            author_name = author.get("given", "") + " " + author.get("family", "")
            affiliations = author.get("affiliation", [])
            school_names = (
                [affil.get("name") for affil in affiliations]
                if affiliations != []
                else ["No Affiliation"]
            )
            # Create a new dictionary with only 'name' and 'affiliation'
            authors[i] = {
                "name": author_name.strip(),
                "affiliation": school_names,
            }
    else:
        authors = sch_paper.get("authors")
        for i in range(len(authors)):
            author = authors[i]
            affiliations = author.get("affiliations")
            if affiliations is None:
                author_name = author["name"]
                affiliations = ["No Affiliation"]

            authors[i] = {
                "name": author_name.strip(),
                "affiliation": affiliations,
            }

    return authors

# %%
def extract_data(row):
    pid = row["ID"]
    if "URL" in pid and "abs-" in pid:
        pid = "arXiv:" + pid.split("abs-")[1].replace("-", ".")

    api_url = f"https://api.semanticscholar.org/graph/v1/paper/{pid}"

    sch_paper = extract_sch(api_url, sch_fields)

    if sch_paper.get("error") is not None:
        # if can't search with ID, search by paper title

        api_url = f"https://api.semanticscholar.org/graph/v1/paper/search?query={row['PaperTitle']}"

        sch_paper = extract_sch(api_url, sch_fields)

        if len(sch_paper.get("data", [])) == 0:
            return {
                "PaperTitle": row["PaperTitle"],
                "DOI": pid,
                "Authors": None,
                "Abstract": None,
                "Publisher": None,
                "SemanticScholarUrl": None,
                "DoiUrl": None,
                "PublicationDate": None,
                "FieldOfStudy": None,
                "Conference-Journal": None,
                "PublicationTypes": None,
                "SearchString": row["SearchString"],
                "CitationCount": None,
                "SearchedFrom": row["SearchedFrom"],
            }
        else:
            sch_paper = sch_paper["data"][0]

    doi = sch_paper.get("externalIds", {}).get("DOI", None)

    if doi is None and str(row["ID"]).startswith("DOI"):
        doi = row["ID"].split(":")[1]

    try:
        crossref_paper = crossref_work.doi(doi)

    except Exception as e:
        crossref_paper = None

    title = row["PaperTitle"]

    authors = extract_authors(sch_paper, crossref_paper)

    abstract = sch_paper.get("abstract", None)

    sch_url = sch_paper.get("url", None)

    doi_url = f"https://doi.org/{doi}" if doi is not None else None

    publication_date = sch_paper.get("publicationDate", None)

    fields_of_study = sch_paper.get("fieldsOfStudy", [])

    venue = sch_paper.get("venue", None)

    # publisher

    if crossref_paper is not None:
        publisher = crossref_paper.get("publisher")

    elif doi and "arxiv" in doi.lower():
        publisher = "arXiv"
    else:
        publisher = None

    # paper type

    if crossref_paper is not None and crossref_paper.get("type") is not None:
        paper_type = [crossref_paper.get("type")]
    else:
        paper_type = sch_paper.get("publicationTypes", [])
        if paper_type is not None:
            paper_type = ["".join(t.split("-")).lower() for t in paper_type]

    citation_count = sch_paper.get("citationCount", None)

    # TODO: paper keywords missing

    # TODO: paper type is conference/journal for arxiv papers

    # TODO: conference-journal name mismatch with publisher, i.e., for paper with name"ChatGPT in education: A discourse analysis of worries and concerns on social media", the conference name is "International Conference on Artificial Intelligence in Education", but the publisher is "Arxiv" (becauseit queryed from arxiv), need "Springer" instead.

    new_paper = {
        "PaperTitle": title,
        "DOI": doi,
        "Authors": authors,
        "Abstract": abstract,
        "Publisher": publisher,
        "SemanticScholarUrl": sch_url,
        "DoiUrl": doi_url,
        "PublicationDate": publication_date,
        "FieldOfStudy": fields_of_study,
        "Conference-Journal": venue,
        "PublicationTypes": paper_type,
        "SearchString": row["SearchString"],
        "CitationCount": citation_count,
        "SearchedFrom": row["SearchedFrom"],
    }

    return new_paper

# %%
for raw_df_path in raw_dfs:
    raw_df = pd.read_csv(raw_df_path)
    total_rows = len(raw_df)
    results = []
    
    # raw_df = raw_df.iloc[2571:]

    for index, row in raw_df.iterrows():
        # if index >= 5:
        #     break
        print(f"Processing {raw_df_path}: row {index + 1}/{total_rows}...")
        paper = extract_data(row)
        results.append(paper)

    # Creating a DataFrame from the results
    results_df = pd.DataFrame(results, columns=columns)

    # Generating a new file name based on the raw data file name
    new_file_name = raw_df_path.replace(".csv", "-full.csv")
    # new_file_name = 'test.csv'

    # Saving to a CSV file
    results_df.to_csv(new_file_name, index=False)
# Out:
# Processing data/cleaned/social/search-results-master-v3.csv: row 1/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 2/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 3/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 4/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 5/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 6/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 7/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 8/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 9/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 10/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 11/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 12/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 13/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 14/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 15/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 16/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 17/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 18/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 19/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 20/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 21/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 22/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 23/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 24/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 25/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 26/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 27/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 28/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 29/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 30/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 31/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 32/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 33/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 34/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 35/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 36/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 37/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 38/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 39/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 40/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 41/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 42/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 43/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 44/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 45/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 46/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 47/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 48/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 49/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 50/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 51/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 52/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 53/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 54/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 55/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 56/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 57/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 58/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 59/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 60/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 61/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 62/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 63/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 64/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 65/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 66/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 67/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 68/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 69/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 70/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 71/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 72/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 73/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 74/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 75/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 76/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 77/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 78/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 79/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 80/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 81/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 82/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 83/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 84/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 85/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 86/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 87/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 88/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 89/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 90/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 91/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 92/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 93/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 94/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 95/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 96/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 97/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 98/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 99/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 100/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 101/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 102/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 103/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 104/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 105/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 106/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 107/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 108/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 109/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 110/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 111/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 112/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 113/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 114/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 115/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 116/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 117/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 118/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 119/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 120/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 121/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 122/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 123/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 124/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 125/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 126/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 127/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 128/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 129/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 130/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 131/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 132/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 133/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 134/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 135/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 136/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 137/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 138/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 139/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 140/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 141/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 142/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 143/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 144/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 145/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 146/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 147/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 148/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 149/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 150/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 151/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 152/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 153/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 154/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 155/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 156/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 157/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 158/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 159/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 160/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 161/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 162/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 163/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 164/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 165/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 166/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 167/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 168/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 169/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 170/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 171/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 172/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 173/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 174/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 175/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 176/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 177/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 178/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 179/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 180/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 181/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 182/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 183/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 184/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 185/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 186/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 187/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 188/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 189/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 190/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 191/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 192/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 193/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 194/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 195/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 196/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 197/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 198/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 199/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 200/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 201/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 202/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 203/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 204/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 205/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 206/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 207/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 208/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 209/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 210/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 211/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 212/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 213/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 214/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 215/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 216/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 217/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 218/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 219/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 220/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 221/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 222/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 223/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 224/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 225/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 226/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 227/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 228/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 229/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 230/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 231/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 232/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 233/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 234/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 235/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 236/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 237/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 238/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 239/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 240/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 241/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 242/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 243/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 244/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 245/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 246/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 247/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 248/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 249/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 250/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 251/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 252/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 253/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 254/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 255/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 256/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 257/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 258/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 259/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 260/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 261/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 262/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 263/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 264/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 265/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 266/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 267/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 268/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 269/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 270/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 271/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 272/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 273/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 274/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 275/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 276/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 277/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 278/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 279/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 280/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 281/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 282/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 283/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 284/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 285/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 286/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 287/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 288/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 289/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 290/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 291/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 292/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 293/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 294/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 295/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 296/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 297/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 298/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 299/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 300/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 301/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 302/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 303/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 304/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 305/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 306/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 307/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 308/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 309/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 310/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 311/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 312/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 313/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 314/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 315/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 316/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 317/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 318/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 319/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 320/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 321/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 322/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 323/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 324/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 325/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 326/2066...
# Processing data/cleaned/social/search-results-master-v3.csv: row 327/2066...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 12
#       8 for index, row in raw_df.iterrows():
#       9     # if index >= 5:
#      10     #     break
#      11     print(f"Processing {raw_df_path}: row {index + 1}/{total_rows}...")
# ---> 12     paper = extract_data(row)
#      13     results.append(paper)
#      15 # Creating a DataFrame from the results
#
# Cell In[8], line 50, in extract_data(row)
#      46     crossref_paper = None
#      48 title = row["PaperTitle"]
# ---> 50 authors = extract_authors(sch_paper, crossref_paper)
#      52 abstract = sch_paper.get("abstract", None)
#      54 sch_url = sch_paper.get("url", None)
#
# Cell In[7], line 59, in extract_authors(sch_paper, crossref_paper)
#      57 else:
#      58     authors = sch_paper.get("authors")
# ---> 59     for i in range(len(authors)):
#      60         author = authors[i]
#      61         affiliations = author.get("affiliations")
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# # Post-processing stuff

# %%
filename = "./data/cleaned/edu/search-results-master-v3-full.csv"

# %%
df_clean = pd.read_csv(filename)
df_clean
# Out:
#                                             PaperTitle  \
# 0    Can we use ChatGPT for Mental Health and Subst...
# 1    Ethical implications of ChatGPT in higher educ...
# 2    Engineering Education in the Era of ChatGPT: P...
# 3    Developing authentic assessment through open e...
# 4    Artificial intelligence in developing countrie...
# ..                                                 ...
# 570  The Covid-19 pandemic: An opportunity for refl...
# 571  Studying the effect of AI Code Generators on S...
# 572  Artificial Hallucinations by Google Bard: Thin...
# 573  Exploring the role of ChatGPT in patient care ...
# 574  AN ANALYSIS OF THE MUSICAL PHILOSOPHY OF MODER...
#
#                                    DOI  \
# 0                        10.2196/51243
# 1            10.48550/arXiv.2311.14378
# 2    10.1109/EDUCON54358.2023.10125121
# 3              10.14742/apubs.2023.657
# 4            10.1177/02666669231200628
# ..                                 ...
# 570  10.17159/2224-7912/2020/V60N4-2A1
# 571            10.1145/3544548.3580919
# 572               10.7759/cureus.43313
# 573        10.1101/2023.06.13.23291311
# 574            10.24204/ejpr.2021.3844
#
#                                                Authors  \
# 0    [{'name': 'Sophia Spallek', 'affiliation': ['N...
# 1    [{'name': 'Ming Li', 'affiliation': ['Northwes...
# 2    [{'name': 'Junaid Qadir', 'affiliation': ['Pro...
# 3    [{'name': 'Mais Fatayer', 'affiliation': ['Uni...
# 4    [{'name': 'Nishith Reddy Mannuru', 'affiliatio...
# ..                                                 ...
# 570  [{'name': 'B. Olivier', 'affiliation': ['Penn ...
# 571  [{'name': 'Majeed Kazemitabaar', 'affiliation'...
# 572  [{'name': 'Mukesh Kumar', 'affiliation': ['API...
# 573  [{'name': 'R. Garg', 'affiliation': ['PostDoct...
# 574  [{'name': 'Peifan Li', 'affiliation': ['The Un...
#
#                                               Abstract Publisher  \
# 0    Background The use of generative artificial in...       NaN
# 1    This scoping review explores the ethical chall...     arXiv
# 2    Engineering education is constantly evolving t...       NaN
# 3    This Pecha Kucha presentation will showcase Th...       NaN
# 4    This paper explores the potential impact of Ge...       NaN
# ..                                                 ...       ...
# 570  The present article poses the question, whethe...       NaN
# 571  AI code generators like OpenAI Codex have the ...       NaN
# 572  One of the critical challenges posed by artifi...       NaN
# 573  Background ChatGPT(Chat Generative Pre-trained...       NaN
# 574  Three variables were considered in this study:...       NaN
#
#                                     SemanticScholarUrl  \
# 0    https://www.semanticscholar.org/paper/083509bb...
# 1    https://www.semanticscholar.org/paper/7611de3f...
# 2    https://www.semanticscholar.org/paper/d553d008...
# 3    https://www.semanticscholar.org/paper/1e0f6f05...
# 4    https://www.semanticscholar.org/paper/5a5e03c3...
# ..                                                 ...
# 570  https://www.semanticscholar.org/paper/f7362485...
# 571  https://www.semanticscholar.org/paper/f03f39f7...
# 572  https://www.semanticscholar.org/paper/0049f577...
# 573  https://www.semanticscholar.org/paper/1c2a3841...
# 574  https://www.semanticscholar.org/paper/2c5426a0...
#
#                                                 DoiUrl PublicationDate  \
# 0                        https://doi.org/10.2196/51243      2023-07-26
# 1            https://doi.org/10.48550/arXiv.2311.14378      2023-11-24
# 2    https://doi.org/10.1109/EDUCON54358.2023.10125121      2023-05-01
# 3              https://doi.org/10.14742/apubs.2023.657      2023-11-28
# 4            https://doi.org/10.1177/02666669231200628      2023-09-14
# ..                                                 ...             ...
# 570  https://doi.org/10.17159/2224-7912/2020/V60N4-2A1             NaN
# 571            https://doi.org/10.1145/3544548.3580919      2023-02-15
# 572               https://doi.org/10.7759/cureus.43313      2023-08-01
# 573        https://doi.org/10.1101/2023.06.13.23291311      2023-06-14
# 574            https://doi.org/10.24204/ejpr.2021.3844      2022-09-10
#
#               FieldOfStudy                                 Conference-Journal  \
# 0             ['Medicine']                             JMIR Medical Education
# 1     ['Computer Science']                                          arXiv.org
# 2     ['Computer Science']       IEEE Global Engineering Education Conference
# 3                      NaN                              ASCILITE Publications
# 4                      NaN                            Information Development
# ..                     ...                                                ...
# 570  ['Political Science']                                                NaN
# 571   ['Computer Science']  International Conference on Human Factors in C...
# 572           ['Medicine']                                             Cureus
# 573           ['Medicine']                                            medRxiv
# 574                    NaN        European Journal for Philosophy of Religion
#
#                                PublicationTypes  \
# 0                            ['journalarticle']
# 1                  ['journalarticle', 'review']
# 2    ['journalarticle', 'conference', 'review']
# 3                            ['journalarticle']
# 4                            ['journalarticle']
# ..                                          ...
# 570                                         NaN
# 571    ['journalarticle', 'book', 'conference']
# 572             ['journalarticle', 'editorial']
# 573                ['journalarticle', 'review']
# 574                                         NaN
#
#                                           SearchString  CitationCount  \
# 0    "Generative Artificial Intelligence" + "misinf...            0.0
# 1    "Generative Artificial Intelligence" + "misinf...            1.0
# 2    "Generative Artificial Intelligence" + "misinf...          154.0
# 3    "Generative Artificial Intelligence" + "access...            0.0
# 4    "Generative Artificial Intelligence" + "access...            3.0
# ..                                                 ...            ...
# 570                  "PaLM" "responsible" "education"             1.0
# 571               "GPT-3" "over-reliance" "education"            53.0
# 572                "GPT" "misinformation" "education"             4.0
# 573                       "GPT" "privacy" "education"             7.0
# 574              "Claude" "environmental" "education"             2.0
#
#          SearchedFrom
# 0    Semantic Scholar
# 1    Semantic Scholar
# 2    Semantic Scholar
# 3    Semantic Scholar
# 4    Semantic Scholar
# ..                ...
# 570    Web of Science
# 571    Web of Science
# 572    Web of Science
# 573    Web of Science
# 574    Web of Science
#
# [575 rows x 14 columns]

# %%
# drop column 'ID'
df_clean = df_clean.drop(columns=["ID"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 2
#       1 # drop column 'ID'
# ----> 2 df_clean = df_clean.drop(columns=["ID"])
#
# File ~/projects/publication_scraper/.venv/lib/python3.10/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/projects/publication_scraper/.venv/lib/python3.10/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/projects/publication_scraper/.venv/lib/python3.10/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/projects/publication_scraper/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['ID'] not found in axis"

# %%
def cast_affliation(authors):
  if authors == np.nan or type(authors) != str:
    return authors
  print(authors)
  authors = eval(authors)
  for i in range(len(authors)):
    author = dict(authors[i])
    if type(author["affiliation"]) is str:
      print(author["affiliation"])
      author["affiliation"] = [author["affiliation"]]
    authors[i] = author
  return authors

# %%
df_clean["Authors"] = df_clean["Authors"].apply(lambda x: cast_affliation(x))
# Out:
# [{'name': 'Sophia Spallek', 'affiliation': ['No Affiliation']}, {'name': 'L. Birrell', 'affiliation': ['The Matilda Centre, The University of Sydney']}, {'name': 'Stephanie Kershaw', 'affiliation': ['No Affiliation']}, {'name': 'E. Devine', 'affiliation': ['University of Maryland School of Medicine']}, {'name': 'Louise Thornton', 'affiliation': ['University of Sydney']}]
# [{'name': 'Ming Li', 'affiliation': ['Northwest A & F University, China']}, {'name': 'Ariunaa Enkhtur', 'affiliation': ['Osaka University']}, {'name': 'Fei Cheng', 'affiliation': ['The Hong Kong University of Science and Technology']}, {'name': 'B. Yamamoto', 'affiliation': ['']}]
# [{'name': 'Junaid Qadir', 'affiliation': ['Professor of Computer Engineering, Qatar University (QU)']}]
# [{'name': 'Mais Fatayer', 'affiliation': ['University of Technology, Sydney']}, {'name': 'Dimity Wehr', 'affiliation': ['No Affiliation']}]
# [{'name': 'Nishith Reddy Mannuru', 'affiliation': ['No Affiliation']}, {'name': 'Sakib Shahriar', 'affiliation': ['University of Guelph']}, {'name': 'Z. A. Teel', 'affiliation': ['Senior Medical Scientist, University of Pretoria']}, {'name': 'Ting Wang', 'affiliation': ['Professor of Physics, Huazhong University of Science & Technology']}, {'name': 'Brady D. Lund', 'affiliation': ['University of North Texas']}, {'name': 'Solomon Tijani', 'affiliation': ['No Affiliation']}, {'name': 'Chalermchai Oak Pohboon', 'affiliation': ['No Affiliation']}, {'name': 'Daniel A. Agbaji', 'affiliation': ['UNT']}, {'name': 'Joy Alhassan', 'affiliation': ['No Affiliation']}, {'name': 'JaKLyn Galley', 'affiliation': ['No Affiliation']}, {'name': 'Raana Kousari', 'affiliation': ['Phd candidate in Medical library & information science, Iran University of Medical Science']}, {'name': 'Lydia Ogbadu-Oladapo', 'affiliation': ['University of North Texas']}, {'name': 'Shubham Kumar Saurav', 'affiliation': ['No Affiliation']}, {'name': 'Aishwarya Srivastava', 'affiliation': ['Clemson University']}, {'name': 'Sai Priya Tummuru', 'affiliation': ['No Affiliation']}, {'name': 'Sravya Uppala', 'affiliation': ['No Affiliation']}, {'name': 'Praveenkumar Vaidya', 'affiliation': ['Librarian, Christ (Deemed to be University). Bengaluru. Pune Lavasa Campus']}]
# [{'name': 'Richard McInnes', 'affiliation': ['The University of Adelaide']}, {'name': 'Mark Carandang', 'affiliation': ['No Affiliation']}, {'name': 'Ajay Kulkarni', 'affiliation': ['Engineering Manager']}]
# [{'name': 'T. Farrelly', 'affiliation': ['PsiQuantum']}, {'name': 'Nick Baker', 'affiliation': ['A-STAR Institute of Molecular and Cellular Biology, Singapore']}]
# [{'name': 'Austin Pack', 'affiliation': ['Brigham Young University Hawaii']}, {'name': 'J. Maloney', 'affiliation': ['Consulting Engineering (jmaloney65@gmail.com)']}]
# [{'name': 'Yanwei You', 'affiliation': ['… of Food Science and Technology, Nanchang University,Department of Chemistry, U …']}, {'name': 'Yuquan Chen', 'affiliation': ['Peng Cheng Laboratory']}, {'name': 'Yujun You', 'affiliation': ['shanghai institute of technology']}, {'name': 'Qi Zhang', 'affiliation': ['Shanghai Jiao Tong University']}, {'name': 'Qiang Cao', 'affiliation': ['Nanjing Agricultural University']}]
# [{'name': 'Arne Bewersdorff', 'affiliation': ['Post-Doc, Technical University of Munich']}, {'name': 'Christian Hartmann', 'affiliation': ['Professor of Biology, Texas Christian University']}, {'name': 'Marie Hornberger', 'affiliation': ['No Affiliation']}, {'name': 'Kathrin Seßler', 'affiliation': ['Technical University of Munich']}, {'name': 'M. Bannert', 'affiliation': ['University of NSW']}, {'name': 'Enkelejda Kasneci', 'affiliation': ['Professor at the Technical University of Munich']}, {'name': 'G. Kasneci', 'affiliation': ['Professor at the Technical University of Munich']}, {'name': 'Xiaoming Zhai', 'affiliation': ['University of Georgia']}, {'name': 'Claudia Nerdel', 'affiliation': ['Technische Universität München']}]
# [{'name': 'Shakib Sadat Shanto', 'affiliation': ['Student']}, {'name': 'Zishan Ahmed', 'affiliation': ['Associate Professor of Particle Physics and Astrophysics, Stanford University and SLAC …']}, {'name': 'Akinul Islam Jony', 'affiliation': ['No Affiliation']}]
# [{'name': 'Anh Nguyen-Duc', 'affiliation': ['Professor, University of South Eastern Norway, Norwegian University of Science and']}, {'name': 'Beatriz Cabrero Daniel', 'affiliation': ['Postdoc, University of Gothenburg']}, {'name': 'Adam Przybylek', 'affiliation': ['Gdansk University of Technology']}, {'name': 'Chetan Arora', 'affiliation': ['Professor, IIT Delhi']}, {'name': 'Dron Khanna', 'affiliation': ['Research Assistant']}, {'name': 'Tomas Herda', 'affiliation': ['Konzern IT - Austrian Post']}, {'name': 'Usman Rafiq', 'affiliation': ['PhD Candidate, University of Kentucky']}, {'name': 'Jorge Melegati', 'affiliation': ['Researcher, Free University of Bozen-Bolzano']}, {'name': 'Eduardo Guerra', 'affiliation': ['Researcher, Free University of Bozen-Bolzano']}, {'name': 'Kai-Kristian Kemell', 'affiliation': ['Postdoctoral Researcher at University of Helsinki']}, {'name': 'Mika Saari', 'affiliation': ['Tampere University']}, {'name': 'Zheying Zhang', 'affiliation': ['Tampere University']}, {'name': 'Huy Le', 'affiliation': ['Professor of Management, University of Texas at San Antonio']}, {'name': 'Tho Quan', 'affiliation': ['']}, {'name': 'P. Abrahamsson', 'affiliation': ['Professor of Software Engineering at Tampere University, Finland']}]
# [{'name': 'M. Kuzlu', 'affiliation': ['Old Dominion University']}, {'name': 'Zhenxin Xiao', 'affiliation': ['Carnegie Mellon University']}, {'name': 'S. Sarp', 'affiliation': ['Senior Statistician, MRC Epidemiology Unit, University of Cambridge']}, {'name': 'Ferhat Ozgur Catak', 'affiliation': ['Assoc. Professor of Cyber Security at University of Stavanger']}, {'name': 'Necip Gurler', 'affiliation': ['VP of R&D at eKare Inc.']}, {'name': 'Ozgur Guler', 'affiliation': ['CTO and co-founder at eKare Inc.']}]
# [{'name': 'David Baidoo-Anu', 'affiliation': ["Queen's University, Canada."]}, {'name': 'Leticia Owusu Ansah', 'affiliation': ['UNIVERSITY OF CAPE COAST']}]
# [{'name': 'K. Wach', 'affiliation': ['Cracow University of Economics']}, {'name': 'Cong Doanh Duong', 'affiliation': ['Assoc. Prof., National Economics University, Vietnam']}, {'name': 'J. Ejdys', 'affiliation': ['Professor/Białystok University of Technology, Faculty of Engineering Management']}, {'name': 'Rūta Kazlauskaitė', 'affiliation': ['ISM University of Management and Economics']}, {'name': 'P. Korzyński', 'affiliation': ['Department of Internal Medicine, Pulmonary Diseases and Allergy, Medical University of …']}, {'name': 'G. Mazurek', 'affiliation': ['Professor of Marketing, Kozminski University; Profesor Marketingu, Akademia Leona']}, {'name': 'Joanna Paliszkiewicz', 'affiliation': ['Warsaw University of Life Sciences']}, {'name': 'E. Ziemba', 'affiliation': ['Professor at University of Economics in Katowice / Uniwersytet Ekonomiczny w Katowicach']}]
# [{'name': 'S. Sharma', 'affiliation': ["Cardiology clinical and academic group. St George's University of London and St George's …"]}, {'name': 'J. Ramchandani', 'affiliation': ['']}, {'name': 'A. Thakker', 'affiliation': ['Professor Emeritus of Chemistry, University of New Brunswick']}, {'name': 'A. Lahiri', 'affiliation': ['The Australian National University']}]
# [{'name': 'Haotian Yu', 'affiliation': ['NJUST']}, {'name': 'Yunyun Guo', 'affiliation': ['No Affiliation']}]
# [{'name': 'Yunshu Ni', 'affiliation': ['No Affiliation']}, {'name': 'Bo Peng', 'affiliation': ['Computational Scientist, Pacific Northwest National Library']}, {'name': 'Siqi Yang', 'affiliation': ['University of Electronic Science and Technology of China']}]
# [{'name': 'C. Chang', 'affiliation': ['Professor of Physics, Kyungpook National University']}, {'name': 'G. Kidman', 'affiliation': ['A/Prof. Science Education, Monash University']}]
# [{'name': 'G. Cooper', 'affiliation': ['Professor Emeritus, McMaster University, Canada']}]
# [{'name': 'Oliver Gassmann', 'affiliation': ['University of St.Gallen']}, {'name': 'Naomi Haefner', 'affiliation': ['Assistant Professor of Technology Management, University of St. Gallen']}, {'name': 'David M. Wagner', 'affiliation': ['Professor of Biological Sciences, Northern Arizona University']}]
# [{'name': 'C. Schuengel', 'affiliation': ['professor of Clinical Child and Family Studies, Vrije Universiteit Amsterdam']}, {'name': 'A. van Heerden', 'affiliation': ['Research Director, Human Sciences Research Council']}]
# [{'name': 'F. Megahed', 'affiliation': ['University Faculty Scholar, Miami University']}, {'name': 'Ying-Ju Chen', 'affiliation': ['Hong Kong University of Science and Technology']}, {'name': 'Joshua A. Ferris', 'affiliation': ['Assistant Lecturer, Miami University']}, {'name': 'S. Knoth', 'affiliation': ['']}, {'name': 'L. A. Jones‐Farmer', 'affiliation': ['Van Andel Professor of Analytics, Miami University']}]
# [{'name': 'Tama Leaver', 'affiliation': ['Professor of Internet Studies, Curtin University']}, {'name': 'Suzanne Srdarov', 'affiliation': ['No Affiliation']}]
# [{'name': 'Yangin Yoon', 'affiliation': ['No Affiliation']}]
# [{'name': 'Lidia Marassi', 'affiliation': ['No Affiliation']}]
# [{'name': 'Xiaying Li', 'affiliation': ['Colorado State University']}, {'name': 'Belle Li', 'affiliation': ['AI pioneer (Bell Labs, IBM, Stanford University)']}, {'name': 'Su-Je Cho', 'affiliation': ['Fordham University']}]
# [{'name': 'Kevin Kuck', 'affiliation': ['Vrije Universiteit Amsterdam || Aalto University']}]
# [{'name': 'S. Koga', 'affiliation': ['Kobe Design University']}]
# [{'name': 'Kim Taylor', 'affiliation': ["Assoc Prof of Media Literacy, Taylor's University and Universiti Kebangsaan Malaysia"]}]
# [{'name': 'Sara Wilson', 'affiliation': ['Mechanical Engineering, Bioengineering, University of Kansas']}, {'name': 'Matthew Nishomoto', 'affiliation': ['No Affiliation']}]
# [{'name': 'Christopher B Divito', 'affiliation': ['No Affiliation']}, {'name': 'Bryan M Katchikian', 'affiliation': ['No Affiliation']}, {'name': 'Jenna E Gruenwald', 'affiliation': ['No Affiliation']}, {'name': 'Jennifer M Burgoon', 'affiliation': ['No Affiliation']}]
# [{'name': 'Amanda Baskwill', 'affiliation': ['Loyalist College']}]
# [{'name': 'Zied Bahroun', 'affiliation': ['American University of Sharjah']}, {'name': 'Chiraz Anane', 'affiliation': ['Instructor, French language']}, {'name': 'Vian Ahmed', 'affiliation': ['American University of Sharjah']}, {'name': 'Andrew Zacca', 'affiliation': ['No Affiliation']}]
# [{'name': 'Zhicheng Lin', 'affiliation': ['McLean Hospital']}]
# [{'name': 'Niina Zuber', 'affiliation': ['Senior Research']}, {'name': 'Jan Gogoll', 'affiliation': ['Technische Universität München/ Bavarian Academy of Sciences and Humanities']}]
# [{'name': 'Nayiri Keshishi', 'affiliation': ['No Affiliation']}, {'name': 'Dr Sarah Hack', 'affiliation': ['No Affiliation']}]
# [{'name': 'C. Chan', 'affiliation': ['The University of Hong Kong']}, {'name': 'Katherine K. W. Lee', 'affiliation': ['No Affiliation']}]
# [{'name': 'Lauren J. Woo', 'affiliation': ['Ph.D. Student, Mary Lou Fulton Teachers College, Arizona State University']}, {'name': 'D. Henriksen', 'affiliation': ['Associate Professor of Educational Leadership and Innovation']}, {'name': 'Punya Mishra', 'affiliation': ["Assoc. Dean of Scholarship & Innovation, Mary Lou Fulton Teacher's College, Arizona State"]}]
# [{'name': 'Charles la Shure', 'affiliation': ['No Affiliation']}]
# [{'name': 'Matthias Wölfel', 'affiliation': ['Karlsruhe University of Applied Sciences, University of Hohenheim, and ColorfulBit']}, {'name': 'Mehrnoush Barani Shirzad', 'affiliation': ['Data Mining Laboratory, Department of Computer Engineering, Alzahra University']}, {'name': 'Andreas Reich', 'affiliation': ['PhD Student, University of the Bundeswehr Munich']}, {'name': 'Katharina Anderer', 'affiliation': ['No Affiliation']}]
# [{'name': 'Andrew Caines', 'affiliation': ['University of Cambridge']}, {'name': 'Luca Benedetto', 'affiliation': ['Postdoc Research Associate, University of Cambridge']}, {'name': 'Shiva Taslimipoor', 'affiliation': ['Research Associate, University of Cambridge']}, {'name': 'Christopher Davis', 'affiliation': ['Professor Comparative Ophthalmology UC, Davis']}, {'name': 'Yuan Gao', 'affiliation': ['PHD student in Electronics Engineering, University of Bristol']}, {'name': 'Oeistein Andersen', 'affiliation': ['No Affiliation']}, {'name': 'Zheng Yuan', 'affiliation': ['National Institutes of Health']}, {'name': 'Mark Elliott', 'affiliation': ['Consultant Respiratory Physician, Leeds, UK']}, {'name': 'Russell Moore', 'affiliation': ['Univeristy of Colorado']}, {'name': 'Christopher Bryant', 'affiliation': ['LS Randolph Professor of Mechanical Engineering, Virginia Tech']}, {'name': 'Marek Rei', 'affiliation': ['Lecturer, Imperial College London']}, {'name': 'H. Yannakoudakis', 'affiliation': ["Lecturer, King's College London"]}, {'name': 'Andrew Mullooly', 'affiliation': ['No Affiliation']}, {'name': 'D. Nicholls', 'affiliation': ['Buck Institute for Research on Aging']}, {'name': 'P. Buttery', 'affiliation': ['Research Associate - Butterfly Genetics Group (Cambridge University)']}]
# [{'name': 'Benedikt Fecher', 'affiliation': ['Alexander von Humboldt Institute for Internet and Society']}, {'name': 'Marcel Hebing', 'affiliation': ['No Affiliation']}, {'name': 'M. Laufer', 'affiliation': ['CVD, University of Maryland']}, {'name': 'Jörg Pohle', 'affiliation': ['Alexander von Humboldt Institute for Internet and Society']}, {'name': 'Fabian Sofsky', 'affiliation': ["Master's student, Technical University of Munich"]}]
# [{'name': 'Ilinca Barsan', 'affiliation': ['No Affiliation']}, {'name': 'Ching-Hua Chuan', 'affiliation': ['University of Miami']}, {'name': 'Luisa Martinez', 'affiliation': ['Professor Nottingham University']}, {'name': 'Christopher Neff', 'affiliation': ['']}, {'name': 'Wan-Hsiu Sunny Tsai', 'affiliation': ['No Affiliation']}, {'name': 'Jing Yang', 'affiliation': ['National Yang Ming Chiao Tung University']}, {'name': 'Edward E. Timke', 'affiliation': ['Retired Assoc. Professor of CS and ECE at CMU']}]
# [{'name': 'Chirag Shah', 'affiliation': ['Professor, University of Washington']}]
# [{'name': 'Tat Putjorn', 'affiliation': ['No Affiliation']}, {'name': 'Pruet Putiorn', 'affiliation': ['No Affiliation']}]
# [{'name': 'Ashish Amresh', 'affiliation': ['Associate Professor, Northern Arizona University']}]
# [{'name': 'Victor Berardi', 'affiliation': ['Associate Professor, Information Systems & Business Analytics, Kent State University']}, {'name': 'Vaneet Kaur', 'affiliation': ['Assistant Professor of Management at Kent State University']}, {'name': 'Donald Thacker', 'affiliation': ['No Affiliation']}, {'name': 'G. Blundell', 'affiliation': ['']}]
# [{'name': 'Tung Phung', 'affiliation': ['Director of Mekong Development Research Institute']}, {'name': 'Victor-Alexandru Pădurean', 'affiliation': ['PhD Student, Max Planck Institute for Software Systems']}, {'name': 'J. Cambronero', 'affiliation': ['Professor of Biochemistry and Molecular Biology']}, {'name': 'Sumit Gulwani', 'affiliation': ['Partner Research Manager, Microsoft']}, {'name': 'Tobias Kohn', 'affiliation': ['University of Technology Sydney']}, {'name': 'R. Majumdar', 'affiliation': ['MPI for Software Systems']}, {'name': 'A. Singla', 'affiliation': ['Head Single Molecule Neuroscience Lab, Queensland Brain Institute, The University of …']}, {'name': 'Gustavo Soares', 'affiliation': ['']}]
# [{'name': 'Su-Yen Chen', 'affiliation': ['No Affiliation']}]
# [{'name': 'Jaromír Šavelka', 'affiliation': ['Carnegie Mellon University']}, {'name': 'Arav Agarwal', 'affiliation': ['Masters Student, Carnegie Mellon University']}, {'name': 'Marshall An', 'affiliation': ['University of Cambridge']}, {'name': 'C. Bogart', 'affiliation': ['Systems Scientist, Carnegie Mellon University']}, {'name': 'M. Sakr', 'affiliation': ['Arab Academy for Science, Technology and Maritime Transport']}]
# [{'name': 'F. Sağın', 'affiliation': ['YEDITEPE UNIVERSITESI']}, {'name': 'Ali Burak Özkaya', 'affiliation': ['İzmir University of Economics']}, {'name': 'F. Tengiz', 'affiliation': ['Tıp Fakültesi Tıp Eğitimi Yardımcı Doçent, İzmir Katip Çelebi Üniversitesi']}, {'name': 'Ö. G. Geyik', 'affiliation': ['Istinye University']}, {'name': 'Caner Geyik', 'affiliation': ['İstinye University']}]
# [{'name': 'Theodore W. Frick', 'affiliation': ['Professor Emeritus, School of Education, Indiana University']}]
# [{'name': 'Isidora Chara Tourni', 'affiliation': ['Boston University']}, {'name': 'G. Grigorakis', 'affiliation': ['No Affiliation']}, {'name': 'Isidoros Marougkas', 'affiliation': ['PhD Student, Rutgers University']}, {'name': 'Konstantinos M. Dafnis', 'affiliation': ['Rutgers University']}, {'name': 'Vassiliki‐Panagiota Tassopoulou', 'affiliation': ['No Affiliation']}]
# [{'name': 'Yijun Gao', 'affiliation': ['Sun Yat-sen University Cancer Center']}, {'name': 'Amanda Herrmann', 'affiliation': ['No Affiliation']}, {'name': 'Chun Chen', 'affiliation': ['Department of Chemical Engineering, Ming Chi University of Technology (明志科技大學化學 …']}]
# [{'name': 'M. Virvou', 'affiliation': ['Professor, Head of the Department of Informatics, University of Piraeus']}, {'name': 'G. Tsihrintzis', 'affiliation': ['Professor, University of Piraeus']}]
# [{'name': 'Vera G. Dianova', 'affiliation': ['Franklin University Switzerland']}, {'name': 'Mario D. Schultz', 'affiliation': ['Assistant Professor, International Management']}]
# [{'name': 'James Finnie-Ansley', 'affiliation': ['University of Auckland']}, {'name': 'Paul Denny', 'affiliation': ['The University of Queensland']}, {'name': 'Andrew Luxton-Reilly', 'affiliation': ['Professor, Computer Science, University of Auckland']}, {'name': 'E. Santos', 'affiliation': ['aluno de matematica']}, {'name': 'J. Prather', 'affiliation': ['Professor of Zoology and Physiology and Neuroscience, University of Wyoming']}, {'name': 'Brett A. Becker', 'affiliation': ['University College Dublin']}]
# [{'name': 'Eric York', 'affiliation': ['Helen Gould Shepard Professor in the Social Sciences, New York University']}]
# [{'name': 'M. T. Baldassarre', 'affiliation': ['No Affiliation']}, {'name': 'D. Caivano', 'affiliation': ['Professore Dipartimento di Informatica Università degli Studi di Bari Aldo Moro']}, {'name': 'Berenice Fernandez Nieto', 'affiliation': ['IMT Lucca']}, {'name': 'Domenico Gigante', 'affiliation': ['Phd @ Università degli Studi di Bari "A. Moro"']}, {'name': 'A. Ragone', 'affiliation': ['University of Bari "A. Moro"']}]
# [{'name': 'G. Androschuk', 'affiliation': ['No Affiliation']}]
# [{'name': 'C. Chan', 'affiliation': ['The University of Hong Kong']}, {'name': 'Wenjie Hu', 'affiliation': ['The Pennsylvania State University']}]
# [{'name': 'Anmol Arora', 'affiliation': ['research scholar']}, {'name': 'Ananya Arora', 'affiliation': ['No Affiliation']}]
# [{'name': 'Lixiang Yan', 'affiliation': ['Research Fellow, Center for Learning Analytics at Monash (CoLAM), Monash University']}, {'name': 'Lele Sha', 'affiliation': ['Center for Learning Analytics at Monash (CoLAM), Monash University']}, {'name': 'Linxuan Zhao', 'affiliation': ['PhD student at Monash University']}, {'name': 'Yuheng Li', 'affiliation': ['Eric and Wendy Schmidt AI in Science Fellow at NUS; UCSD']}, {'name': 'Roberto Martínez-Maldonado', 'affiliation': ['No Affiliation']}, {'name': 'Guanliang Chen', 'affiliation': ['Reader (Associate Professor) in University of Liverpool']}, {'name': 'Xinyu Li', 'affiliation': ['Penn State University']}, {'name': 'Yueqiao Jin', 'affiliation': ['Department of Public Health Sciences, University of Virginia']}, {'name': 'D. Gašević', 'affiliation': ['Professor of Learning Analytics, Monash University']}]
# [{'name': 'Hui Wang', 'affiliation': ['Wuhan University， Professor']}, {'name': 'Anh Dang', 'affiliation': ['Duy Tan University']}, {'name': 'Zihao Wu', 'affiliation': ['Assistant Professor, Southern Methodist University']}, {'name': 'Son Mac', 'affiliation': ['PhD candidate working on seawater eDNA metabarcoding']}]
# [{'name': 'C. Chan', 'affiliation': ['The University of Hong Kong']}]
# [{'name': 'Brian M. Belgodere', 'affiliation': ['IBM Research']}, {'name': 'Pierre L. Dognin', 'affiliation': ['No Affiliation']}, {'name': 'Adam Ivankay', 'affiliation': ['Doctoral Researcher, IBM Research and EPFL']}, {'name': 'Igor Melnyk', 'affiliation': ['IBM Research']}, {'name': 'Youssef Mroueh', 'affiliation': ['Principal Research Scientist, IBM TJ Watson Research Center']}, {'name': 'A. Mojsilovic', 'affiliation': ['Google Research']}, {'name': 'Jiri Navartil', 'affiliation': ['IBM Research']}, {'name': 'Apoorva Nitsure', 'affiliation': ['Research Software Engineer']}, {'name': 'Inkit Padhi', 'affiliation': ['IBM Research']}, {'name': 'Mattia Rigotti', 'affiliation': ['Researcher at IBM Research AI']}, {'name': 'Jerret Ross', 'affiliation': ['No Affiliation']}, {'name': 'Yair Schiff', 'affiliation': ['Cornell University']}, {'name': 'Radhika Vedpathak', 'affiliation': ['No Affiliation']}, {'name': 'Richard A. Young', 'affiliation': ['Professor of Microbiology and Molecular Biology, Brigham Young University']}]
# [{'name': 'Kadaruddin Kadaruddin', 'affiliation': ['Universiti Kebangsaan Malaysia']}]
# [{'name': 'Mike Urmeneta', 'affiliation': ['Northeastern University']}]
# [{'name': 'J. Dix', 'affiliation': ['paris 10 nanterre']}, {'name': 'Zhongfei Zhang', 'affiliation': ['Professor of comuter science, Binghamton University']}]
# [{'name': 'Haotian Yu', 'affiliation': ['NJUST']}, {'name': 'Zhaoyang Liu', 'affiliation': ['Qatar Environment and Energy Research Institute']}, {'name': 'Yunyun Guo', 'affiliation': ['No Affiliation']}]
# [{'name': 'Edward Palmer', 'affiliation': ['Professor of Ophthalmology, Bascom Palmer Eye Institute, University of Miami']}, {'name': 'Daniel Lee', 'affiliation': ['The University of Melbourne']}, {'name': 'Matthew Arnold', 'affiliation': ['Arnold and Arlene Goldstein Professor of Cardiology, Columbia University']}, {'name': 'Dimitra Lekkas', 'affiliation': ['No Affiliation']}, {'name': 'Katrina Plastow', 'affiliation': ['No Affiliation']}, {'name': 'Florian Ploeckl', 'affiliation': ['School of Economics, University of Adelaide']}, {'name': 'Amit Srivastav', 'affiliation': ['IIT GUWAHATI']}, {'name': 'Peter Strelan', 'affiliation': ['University of Adelaide']}]
# [{'name': 'Ting Wang', 'affiliation': ['Professor of Physics, Huazhong University of Science & Technology']}, {'name': 'Brady D. Lund', 'affiliation': ['University of North Texas']}, {'name': 'A. Marengo', 'affiliation': ['CEMADEN']}, {'name': 'A. Pagano', 'affiliation': ['Professor of Pharmacology & Chemical Biology, PI in the Vascular Medicine Institute']}, {'name': 'Nishith Reddy Mannuru', 'affiliation': ['No Affiliation']}, {'name': 'Z. A. Teel', 'affiliation': ['Senior Medical Scientist, University of Pretoria']}, {'name': 'J. Pange', 'affiliation': ['Monash University']}]
# [{'name': 'Andrew Komoder', 'affiliation': ['No Affiliation']}, {'name': 'Lynnae Venaruzzo', 'affiliation': ['Director, Postgraduate Transformations, Western Sydney University']}, {'name': 'Carmen Young', 'affiliation': ['Department of Paediatrics, Yong Loo Lin School of Medicine, National University of …']}]
# [{'name': 'Andrew Katz', 'affiliation': ['Professor of Neurosurgery, Temple University Louis Katz School of Medicine']}, {'name': 'Umair Shakir', 'affiliation': ['No Affiliation']}, {'name': 'B. Chambers', 'affiliation': ['Department of Biostatistics, Rhode Island Hospital; Department of Medicine, Brown Medical …']}]
# [{'name': 'Irene Hou', 'affiliation': ['Houston Methodist Research Institute, Cornell university, harvard medical school, Tufts …']}, {'name': 'Owen Man', 'affiliation': ['']}, {'name': 'Sophia Mettille', 'affiliation': ['No Affiliation']}, {'name': 'Sebastian Gutierrez', 'affiliation': ['Faculty of Medicine and Science, Universidad San Sebastian']}, {'name': 'Kenneth Angelikas', 'affiliation': ['Temple University']}, {'name': 'Stephen Macneil', 'affiliation': ['Senior Researcher - Geostatistics, Landcare Research New Zealand']}]
# [{'name': 'Vahid Ashrafimoghari', 'affiliation': ['Stevens Institute of Technology']}, {'name': 'Necdet Gurkan', 'affiliation': ['Stevens Institute of Technology']}, {'name': 'Jordan W. Suchow', 'affiliation': ['Stevens Institute of Technology']}]
# [{'name': 'David Cropley', 'affiliation': ['Professor of Engineering Innovation, University of South Australia']}]
# [{'name': 'Anamika Mishra', 'affiliation': ['ICAR-National Institute of High Security Animal Diseases, Bhopal, India']}, {'name': 'Awantika Singh', 'affiliation': ['PhD']}, {'name': 'Prashenjeet Singh', 'affiliation': ['No Affiliation']}, {'name': 'Shailesh Singh', 'affiliation': ['web developer,software developer']}, {'name': 'Shrawan Kumar Pandey', 'affiliation': ['Dept. of Mathematical Sciences, APS University, Rewa (MP) 486003 India']}, {'name': 'Abhinandan Tripathi', 'affiliation': ['Assistant Professor, Computer Science & Engineering, Buddha Institute of Technology …']}]
# [{'name': 'Selcuk Kilinc', 'affiliation': ['Sağlık Bilimleri Üniversitesi Tıbbi KBRN ABD']}]
# [{'name': 'Rosario Michel-Villarreal', 'affiliation': ['Sustainability Research Institute, University of Leeds']}, {'name': 'E. Vilalta-Perdomo', 'affiliation': ['Senior Teaching Fellow - Aston Business School, Aston University']}, {'name': 'D. Salinas-Navarro', 'affiliation': ['Aston Business School, Aston University']}, {'name': 'Ricardo Thierry-Aguilera', 'affiliation': ['No Affiliation']}, {'name': 'F. S. Gerardou', 'affiliation': ['No Affiliation']}]
# [{'name': 'Artur Strzelecki', 'affiliation': ['University of Economics in Katowice']}, {'name': 'Sara ElArabawy', 'affiliation': ['No Affiliation']}]
# [{'name': 'Lars Strannegård', 'affiliation': ['No Affiliation']}]
# [{'name': 'M. Morris', 'affiliation': ['msc physics']}]
# [{'name': 'Abby McGuire', 'affiliation': ['No Affiliation']}]
# [{'name': 'Lingyao Li', 'affiliation': ['University of Michigan, School of Information']}, {'name': 'Zihui Ma', 'affiliation': ['University of Maryland-college park']}, {'name': 'Lizhou Fan', 'affiliation': ['royal institute of technology']}, {'name': 'Sanggyu Lee', 'affiliation': ['National Institute of Fisheries and Science']}, {'name': 'Huizi Yu', 'affiliation': ['University of Michigan, Ann Arbor']}, {'name': 'Libby Hemphill', 'affiliation': ['Associate Professor, University of Michigan School of Information']}]
# [{'name': 'J. C. De Gagne', 'affiliation': ['No Affiliation']}, {'name': 'Hyeyoung Hwang', 'affiliation': ['']}, {'name': 'Dukyoo Jung', 'affiliation': ['']}]
# [{'name': 'Jennifer M Weller-Newton', 'affiliation': ['No Affiliation']}, {'name': 'Annette Burgess', 'affiliation': ['Professor of Medical Education, Sydney Medical School, The University of Sydney']}]
# [{'name': 'Kerstin Denecke', 'affiliation': ['Bern University of Applied Sciences']}, {'name': 'Robin Glauser', 'affiliation': ['Berner Fachhochschule']}, {'name': 'Daniel Reichenpfader', 'affiliation': ['BFH Bern University of Applied Sciences']}]
# [{'name': 'Li-cheng Du', 'affiliation': ['Hong Kong Polytechnic University/Université Laval/Université de Sherbrooke/INSA-Lyon']}, {'name': 'K. Kamenova', 'affiliation': ['Al-Farabi Kazakh National University']}]
# [{'name': 'Andrej Thurzo', 'affiliation': ['Dep.of Orthodontics Regenerative and Forensic Dentistry,Comenius University in Bratislava …']}, {'name': 'Martin Strunga', 'affiliation': ['No Affiliation']}, {'name': 'R. Urban', 'affiliation': ['Full Professor of Regional and Urban Economics']}, {'name': 'Jana Surovková', 'affiliation': ['No Affiliation']}, {'name': 'K. I. Afrashtehfar', 'affiliation': ['Ajman University, College of Dentistry']}]
# [{'name': 'Oscar A Garcia Valencia', 'affiliation': ['Mayo Clinic']}, {'name': 'C. Thongprayoon', 'affiliation': ['Mayo Clinic']}, {'name': 'Caroline C. Jadlowiec', 'affiliation': ['No Affiliation']}, {'name': 'Shennen A. Mao', 'affiliation': ['No Affiliation']}, {'name': 'Jing Miao', 'affiliation': ['The Center for Advanced Computer Studies, University of Louisiana at Lafayette']}, {'name': 'W. Cheungpasitporn', 'affiliation': ['Mayo Clinic']}]
# [{'name': 'Pethigamage Perera', 'affiliation': ['No Affiliation']}, {'name': 'M. Lankathilake', 'affiliation': ['Assistant Librarian,University of Colombo']}]
# [{'name': 'S. Biri', 'affiliation': ['İstanbul Okan Üniversitesi']}, {'name': 'Subir Kumar', 'affiliation': ['CSIR-IMMT, Bhubaneswar']}, {'name': 'Muralidhar Panigrahi', 'affiliation': ['No Affiliation']}, {'name': 'Shaikat Mondal', 'affiliation': ['Analog Engineer']}, {'name': 'J. Behera', 'affiliation': ['Associate Professor']}, {'name': 'Himel Mondal', 'affiliation': ['All India Institute of Medical Sciences, Deoghar, Jharkhand, India']}]
# [{'name': 'L. Krupp', 'affiliation': ['New York University Langone Health']}, {'name': 'Steffen Steinert', 'affiliation': ['Professor of Statistics, University of Waterloo']}, {'name': 'Maximilian Kiefer-Emmanouilidis', 'affiliation': ['Technische Universität Kaiserslautern']}, {'name': 'Karina E. Avila', 'affiliation': ['TU Kaiserslautern']}, {'name': 'P. Lukowicz', 'affiliation': ['Professor of Computer Science, DFKI and University of Kaiserslautern']}, {'name': 'Jochen Kuhn', 'affiliation': ['Professor (full), Chair of Physics Education, Faculty of Physics, Ludwig-Maximilians …']}, {'name': 'Stefan Kuchemann', 'affiliation': ['LMU München']}, {'name': 'Jakob Karolus', 'affiliation': ['DFKI and TU Kaiserslautern']}]
# [{'name': 'Alaa A. Abd-alrazaq', 'affiliation': ['Weill Cornell Medicine-Qatar']}, {'name': 'Rawan AlSaad', 'affiliation': ['Weill Cornell Medicine']}, {'name': 'Dari Alhuwail', 'affiliation': ['Information Science Department, Kuwait University']}, {'name': 'Arfan Ahmed', 'affiliation': ['Professor of Chemistry, King Khalid University']}, {'name': 'P. Healy', 'affiliation': ['Professor of Business Administration, Harvard Business School']}, {'name': 'Syed Latifi', 'affiliation': ['PhD.']}, {'name': 'S. Aziz', 'affiliation': ['King Abdulaziz University, Jedhah, Saudi Arabia']}, {'name': 'R. Damseh', 'affiliation': ['Al-Balqa Applied University']}, {'name': 'Sadam Alabed Alrazak', 'affiliation': ['No Affiliation']}, {'name': 'Javaid Sheikh', 'affiliation': ['Islamic University of Science and Technology (IUST), Awantipora, Jammu and Kashmir …']}]
# [{'name': 'Tony Haoran Feng', 'affiliation': ['PhD Student, The University of Auckland']}, {'name': 'Paul Denny', 'affiliation': ['The University of Queensland']}, {'name': 'Burkhard Wuensche', 'affiliation': ['Assistant Professor of Computer Science, University of Auckland']}, {'name': 'Andrew Luxton-Reilly', 'affiliation': ['Professor, Computer Science, University of Auckland']}, {'name': 'Steffan Hooper', 'affiliation': ['University of Auckland']}]
# [{'name': 'Hazrat Ali', 'affiliation': ['Psychosomatic Medicine Research Center, Imam Khomeini Hospital, Tehran University of …']}, {'name': 'Junaid Qadir', 'affiliation': ['Professor of Computer Engineering, Qatar University (QU)']}, {'name': 'T. Alam', 'affiliation': ['Foundation University Rawalpindi Campus']}, {'name': 'Mowafa J Househ', 'affiliation': ['No Affiliation']}, {'name': 'Zubair Shah', 'affiliation': ['Assistant Professor, College of Science and Engineering, HBKU, Qatar']}]
# [{'name': 'H. Walker', 'affiliation': ['Professor Emeritus, University of Oregon']}]
# [{'name': 'A. Birkun', 'affiliation': ['VI Vernadsky Crimean Federal University']}, {'name': 'A. Gautam', 'affiliation': ['Childcare educator']}]
# [{'name': 'Jinyan Su', 'affiliation': ['No Affiliation']}, {'name': 'Terry Yue Zhuo', 'affiliation': ["CSIRO's Data61 and Monash University"]}, {'name': 'Di Wang', 'affiliation': ['Associated Professor of Immunology, Zhejiang University']}, {'name': 'Preslav Nakov', 'affiliation': ['MBZUAI']}]
# [{'name': 'F. Eggmann', 'affiliation': ['Department of Periodontology, Endodontology, and Cariology; University of Basel']}, {'name': 'R. Weiger', 'affiliation': ['Senior Investigator, National Cancer Institute, National Institutes of Health']}, {'name': 'N. Zitzmann', 'affiliation': ['University of Bremen']}, {'name': 'M. Blatz', 'affiliation': ['Chair, Department of Preventive and Restorative Sciences, University of Pennsylvania …']}]
# [{'name': 'J. Clusmann', 'affiliation': ['Clinician Scientist, RWTH Aachen University']}, {'name': 'F. Kolbinger', 'affiliation': ['Purdue University']}, {'name': 'H. Muti', 'affiliation': ['Prof. dr hab. n. med. dr hc multi']}, {'name': 'Zunamys I Carrero', 'affiliation': ['Else Kroener Fresenius Center for Digital Health, Technical University Dresden, Dresden …']}, {'name': 'Jan-Niklas Eckardt', 'affiliation': ['No Affiliation']}, {'name': 'Narmin Ghaffari Laleh', 'affiliation': ['University Hospital RWTH Aachen']}, {'name': 'C. M. L. Löffler', 'affiliation': ['Ärztin EKFZ / MK1 Uniklinik Dresden']}, {'name': 'Sophie-Caroline Schwarzkopf', 'affiliation': ['No Affiliation']}, {'name': 'Michaela Unger', 'affiliation': ['PhD student at university clinics TU Dresden']}, {'name': 'G. P. Veldhuizen', 'affiliation': ['Physician-Scientist, Else Kroener Fresenius Center for Digital Health, Technical University …']}, {'name': 'Sophia J. Wagner', 'affiliation': ['Technical University Munich, Helmholtz AI']}, {'name': 'Jakob Nikolas Kather', 'affiliation': ['Else Kroener Fresenius Center for Digital Health, Technical University Dresden, Dresden …']}]
# [{'name': 'Rebecca Murphy Lonergan', 'affiliation': ['No Affiliation']}, {'name': 'Jake Curry', 'affiliation': ['']}, {'name': 'Kallpana Dhas', 'affiliation': ['PhD candidate']}, {'name': 'Benno I Simmons', 'affiliation': ['University of Exeter']}]
# [{'name': 'Patty Lopez', 'affiliation': ['Associate Professor, University of California, Berkeley']}]
# [{'name': 'Shan Chen', 'affiliation': ['Foundation of Biological Data Science']}, {'name': 'B. Kann', 'affiliation': ["Dana-Farber Cancer Institute, Brigham and Women's Hospital, Harvard Medical School"]}, {'name': 'M. Foote', 'affiliation': ['University of Chicago']}, {'name': 'H. Aerts', 'affiliation': ['… Leadership Professor in Nursing Professor of Sociology, School of Arts & Sciences Director …']}, {'name': 'G. Savova', 'affiliation': ['Professor, Harvard']}, {'name': 'R. Mak', 'affiliation': ['… of California San Francisco and Priscilla Chan and Mark Zuckerberg San Francisco General']}, {'name': 'D. Bitterman', 'affiliation': ['Harvard Medical School']}]
# [{'name': 'Ruixiang Tang', 'affiliation': ['Rice University']}, {'name': 'Yu-Neng Chuang', 'affiliation': ['Rice University']}, {'name': 'Xia Hu', 'affiliation': ['Associate Professor of Computer Science, Rice University']}]
# [{'name': 'Mahdi Dhaini', 'affiliation': ['Lebanese American University']}, {'name': 'Wessel Poelman', 'affiliation': ['PhD candidate at KU Leuven']}, {'name': 'Ege Erdogan', 'affiliation': ['Ege Üniversitesi Tıp Fakültesi']}]
# [{'name': 'Ehsan Latif', 'affiliation': ['Thompson Rivers University']}, {'name': 'Luyang Fang', 'affiliation': ['Luoyang Institute of Science and Technology']}, {'name': 'Ping Ma', 'affiliation': ['University of Nottingham Ningbo China']}, {'name': 'Xiaoming Zhai', 'affiliation': ['University of Georgia']}]
# [{'name': 'Samia Mouaki-Benani', 'affiliation': ['No Affiliation']}, {'name': 'A. Sheikh', 'affiliation': ['Postdoc, Kent State University and Brookhaven National Lab., USA']}, {'name': 'Joseph P. Hardy', 'affiliation': ['No Affiliation']}, {'name': 'W. Havins', 'affiliation': ['… is the biggest wholesale hair manufacturer in Vietnam. Having a factory spanning over 50']}]
# [{'name': 'T. Han', 'affiliation': ['Royal Holloway, University of London']}, {'name': 'Lisa C. Adams', 'affiliation': ['No Affiliation']}, {'name': 'Jens-Michalis Papaioannou', 'affiliation': ['Research Assistant, Berliner Hochschule für Technik (BHT)']}, {'name': 'Paul Grundmann', 'affiliation': ['Berliner Hochschule für Technik']}, {'name': 'Tom Oberhauser', 'affiliation': ['Berliner Hochschule fuer Technik']}, {'name': 'Alexander Löser', 'affiliation': ['Professor for Data Science and Text-based Information Systems']}, {'name': 'D. Truhn', 'affiliation': ['Oberarzt Radiologie, UK Aachen']}, {'name': 'K. Bressem', 'affiliation': ['AI in Medicine (AIM) @ Harvard-MGB']}]
# [{'name': 'Akshay Ravi', 'affiliation': ['Engineer, Qualcomm']}, {'name': 'Aaron B. Neinstein', 'affiliation': ['University of California, San Francisco']}, {'name': 'Sara G. Murray', 'affiliation': ['No Affiliation']}]
# [{'name': 'Zhao Song', 'affiliation': ['Institute of Materials for Energy and Environment, Qingdao University, China']}, {'name': 'Guangyi Xu', 'affiliation': ['No Affiliation']}, {'name': 'Junze Yin', 'affiliation': ['Boston University']}]
# [{'name': 'Vikas L. Bommineni', 'affiliation': ['No Affiliation']}, {'name': 'Sanaea Bhagwagar', 'affiliation': ['No Affiliation']}, {'name': 'Daniel Balcarcel', 'affiliation': ['Research Professor, Arizona State University']}, {'name': 'Vishal Bommineni', 'affiliation': ['No Affiliation']}, {'name': 'Christos', 'affiliation': ['']}, {'name': 'Davazitkos', 'affiliation': ['No Affiliation']}, {'name': 'Donald Boyer', 'affiliation': ['The University of Western Australia']}]
# [{'name': 'Yi Xie', 'affiliation': ['University of science and technology of china']}, {'name': 'Ishith Seth', 'affiliation': ['Peninsula Health, Monash University, Murdoch Children Research']}, {'name': 'D. Hunter-Smith', 'affiliation': ['Professor of Surgery, Peninsula Clinical School, Central Clinical School, Monash University']}, {'name': 'W. Rozen', 'affiliation': ['']}, {'name': 'M. Seifman', 'affiliation': ['No Affiliation']}]
# [{'name': 'Bochun Cao', 'affiliation': ['Institute for Structural Mechanics, Ruhr University Bochum']}]
# [{'name': 'Jakub Macina', 'affiliation': ['ETH Zurich, AI Center']}, {'name': 'Nico Daheim', 'affiliation': ['TU Darmstadt, ETH Zürich, ELLIS']}, {'name': 'Sankalan Pal Chowdhury', 'affiliation': ['Doctoral Student, ETH Zurich']}, {'name': 'Tanmay Sinha', 'affiliation': ['Assistant Professor, National Institute of Education, Nanyang Technological University']}, {'name': 'Manu Kapur', 'affiliation': ['ETH Zurich']}, {'name': 'Iryna Gurevych', 'affiliation': ['Full Professor, TU Darmstadt; Adjunct Professor, MBZUAI, Abu Dhabi']}, {'name': 'Mrinmaya Sachan', 'affiliation': ['Assistant Professor, ETH Zürich']}]
# [{'name': 'Lianne Roest', 'affiliation': ['No Affiliation']}, {'name': 'H. Keuning', 'affiliation': ['Utrecht University']}, {'name': 'J. Jeuring', 'affiliation': ['Professor of Software Technology for Learning and Teaching, Utrecht University']}]
# [{'name': 'Anupumar Dhanvijay', 'affiliation': ['No Affiliation']}, {'name': 'M. Pinjar', 'affiliation': ['Associate Professor, Department of Physiology, AIIMS, Deoghar, Jharkhand, India']}, {'name': 'N. Dhokane', 'affiliation': ['Dr. Vishwanath Karad MIT World Peace University']}, {'name': 'S. Sorte', 'affiliation': ['University of British Columbia']}, {'name': 'Amita Kumari', 'affiliation': ['Assistant professor of Biological and Environmental Sciences, Shoolini University']}, {'name': 'Himel Mondal', 'affiliation': ['All India Institute of Medical Sciences, Deoghar, Jharkhand, India']}]
# [{'name': 'Yasmina Al Ghadban', 'affiliation': ['No Affiliation']}, {'name': 'Yvonne Lu', 'affiliation': ['Professor of Medicine, Lund University']}, {'name': 'Uday Adavi', 'affiliation': ['No Affiliation']}, {'name': 'Ankita Sharma', 'affiliation': ['University of Guleph']}, {'name': 'Sridevi Gara', 'affiliation': ['No Affiliation']}, {'name': 'Neelanjana Das', 'affiliation': ['Senior Professor, VIT University, Vellore']}, {'name': 'Bhaskar Kumar', 'affiliation': ['Sri Venkateswara College of Engineering and Technology']}, {'name': 'Renu John', 'affiliation': ['Professor, Biomedical Engineering, Indian Institute of Technology Hyderabad']}, {'name': 'Praveen Devarsetty', 'affiliation': ['George Institute for Global Health']}, {'name': 'Jane E. Hirst', 'affiliation': ['No Affiliation']}]
# [{'name': 'Jen-tse Huang', 'affiliation': ['The Chinese University of Hong Kong']}, {'name': 'Wenxuan Wang', 'affiliation': ['Fudan University']}, {'name': 'Eric Li', 'affiliation': ['Joint Institute for VLBI ERIC and Delft University of Technology']}, {'name': 'Man Ho Lam', 'affiliation': ['University of Hong Kong']}, {'name': 'Shujie Ren', 'affiliation': ['']}, {'name': 'Youliang Yuan', 'affiliation': ['PhD student of Computer Science, The Chinese University of Hong Kong (Shenzhen)']}, {'name': 'Wenxiang Jiao', 'affiliation': ['Tencent AI Lab, Senior Researcher']}, {'name': 'Zhaopeng Tu', 'affiliation': ['Principal Researcher, Tencent AI Lab']}, {'name': 'Michael R. Lyu', 'affiliation': ['Professor of Computer Science & Engineering, The Chinese University of Hong Kong']}]
# [{'name': 'M. Virvou', 'affiliation': ['Professor, Head of the Department of Informatics, University of Piraeus']}, {'name': 'G. Tsihrintzis', 'affiliation': ['Professor, University of Piraeus']}]
# [{'name': 'Xuan-Quy Dao', 'affiliation': ['Eastern International University']}, {'name': 'Ngoc-Bich Le', 'affiliation': ['School of Biomedical Engineering, International University, Vietnam National University Ho …']}]
# [{'name': 'A. Yiu', 'affiliation': ['The Hong Kong Polytechnic University; The University of Sydney']}, {'name': 'K. Lam', 'affiliation': ['Chair Professor in Medicine, the University of Hong Kong']}]
# [{'name': 'Nikki M. Barrington', 'affiliation': ['No Affiliation']}, {'name': 'Namit Gupta', 'affiliation': ['Professor of ECE, SVITS,SVVV, Indore (MP)-India']}, {'name': 'Basel Musmar', 'affiliation': ['An-Najah National University']}, {'name': 'David Doyle', 'affiliation': ['Amsterdam UMC']}, {'name': 'Nicholas Panico', 'affiliation': ['No Affiliation']}, {'name': 'Nikhil Godbole', 'affiliation': ['No Affiliation']}, {'name': 'Taylor Reardon', 'affiliation': ['Resident Physician, Henry Ford Health']}, {'name': 'Randy D’Amico', 'affiliation': ['']}]
# [{'name': 'Melanie Schaur', 'affiliation': ['No Affiliation']}, {'name': 'Reinhard Koutny', 'affiliation': ['No Affiliation']}]
# [{'name': 'Krzysztof Edyko', 'affiliation': ['No Affiliation']}, {'name': 'Piotr Petryla', 'affiliation': ['No Affiliation']}, {'name': 'Kamil Ostafin', 'affiliation': ['No Affiliation']}, {'name': 'Mikołaj Minkner', 'affiliation': ['No Affiliation']}, {'name': 'Borys Bieńkowski', 'affiliation': ['No Affiliation']}, {'name': 'Krzysztof Feja', 'affiliation': ['No Affiliation']}, {'name': 'Zuzanna Suwała', 'affiliation': ['No Affiliation']}, {'name': 'Natalia Rektor', 'affiliation': ['No Affiliation']}, {'name': 'Ewa Łuczak', 'affiliation': ['Associate Professor, Institute of English Studies, University of Warsaw']}, {'name': 'Urszula Marchewka', 'affiliation': ['No Affiliation']}]
# [{'name': 'J. Varas', 'affiliation': ['Universidad Técnica Luis Vargas Torres']}, {'name': 'Brandon Valencia Coronel', 'affiliation': ['No Affiliation']}, {'name': 'Ignacio Villagrán', 'affiliation': ['No Affiliation']}, {'name': 'Gabriel Escalona', 'affiliation': ['Pontificia Universidad Católica de Chile']}, {'name': 'Rocío Hernández', 'affiliation': ['University of Córdoba']}, {'name': 'Gregory Schuit', 'affiliation': ['MSc in Engineering Student, Pontifical Catholic University of Chile']}, {'name': 'Valentina Durán', 'affiliation': ['No Affiliation']}, {'name': 'Antonia Lagos-Villaseca', 'affiliation': ['Pontificia Universidad Católica de Chile']}, {'name': 'C. Jarry', 'affiliation': ['Professor in BigData and AI']}, {'name': 'Andres Neyem', 'affiliation': ['Computer Science Department, Pontificia Universidad Católica de Chile']}, {'name': 'P. Achurra', 'affiliation': ['Research Associate, Imperial College London']}]
# [{'name': 'Hyeok Jun Kwon', 'affiliation': ['']}, {'name': 'Jong Tak Lee', 'affiliation': ['No Affiliation']}]
# [{'name': 'Mohammad Abu-Jeyyab', 'affiliation': ['MD, Mutah University']}, {'name': 'S. Alrosan', 'affiliation': ["Saint Luke's Health System, Kansas, USA."]}, {'name': 'I. Alkhawaldeh', 'affiliation': ['Assistant professor']}]
# [{'name': 'Ishith Seth', 'affiliation': ['Peninsula Health, Monash University, Murdoch Children Research']}, {'name': 'Yi Xie', 'affiliation': ['University of science and technology of china']}, {'name': 'W. Rozen', 'affiliation': ['']}]
# [{'name': 'G. Briganti', 'affiliation': ['Dept. of Biomedical, Metabolic and Neural Sciences University of Modena and Reggio …']}]
# [{'name': 'Spencer J. Foutz', 'affiliation': ['No Affiliation']}, {'name': 'Dallin Gillette', 'affiliation': ['No Affiliation']}, {'name': 'C. Vanier', 'affiliation': ['Faculty of pharmacy, Université de Montréal']}, {'name': 'Senator Joseph Hardy', 'affiliation': ['aNUma']}, {'name': 'W. Havins', 'affiliation': ['… is the biggest wholesale hair manufacturer in Vietnam. Having a factory spanning over 50']}]
# [{'name': 'Madhan Jeyaraman', 'affiliation': ['Assistant Professor of Orthopaedics, ACS Medical College and Hospital, Chennai']}, {'name': 'Sangeetha Balaji', 'affiliation': ['Assistant Professor, Sree Balaji Medical College and Hospital']}, {'name': 'Naveen Jeyaraman', 'affiliation': ['No Affiliation']}, {'name': 'S. Yadav', 'affiliation': ['Scholar of PHD in Organic Light Emitting Diode (OLED)']}]
# [{'name': 'Mert Karabacak', 'affiliation': ['Mount Sinai Health System']}, {'name': 'Konstantinos Margetis', 'affiliation': ['No Affiliation']}]
# [{'name': 'Antonio Yaghy', 'affiliation': ['Tufts - New England Eye Center']}, {'name': 'Maria Yaghy', 'affiliation': ['No Affiliation']}, {'name': 'J. A. Shields', 'affiliation': ['No Affiliation']}, {'name': 'C. L. Shields', 'affiliation': ['No Affiliation']}]
# [{'name': 'Maria Sajjad', 'affiliation': ['']}, {'name': 'Rida Saleem', 'affiliation': ['No Affiliation']}]
# [{'name': 'Shubo Tian', 'affiliation': ['Beijing University of Chemical Technology']}, {'name': 'Qiao Jin', 'affiliation': ['Institute of Business and Management, National Yang Ming Chiao Tung University']}, {'name': 'Lana Yeganova', 'affiliation': ['Scientist, National Institutes of Health']}, {'name': 'Po-Ting Lai', 'affiliation': ['National Center for Biotechnology Information (NCBI)']}, {'name': 'Qingqing Zhu', 'affiliation': ['']}, {'name': 'Xiuying Chen', 'affiliation': ['KAUST']}, {'name': 'Yifan Yang', 'affiliation': ['National Institute of Education, Nanyang Technological University']}, {'name': 'Qingyu Chen', 'affiliation': ['Biomedical Informatics & Data Science, Yale University; NCBI-NLM, National Institutes of …']}, {'name': 'Won Kim', 'affiliation': ['Samsung Medical Center']}, {'name': 'Donald C. Comeau', 'affiliation': ['No Affiliation']}, {'name': 'Rezarta Islamaj', 'affiliation': ['National Center for Biotechnology Information, National Library of Medicine, National …']}, {'name': 'Aadit Kapoor', 'affiliation': ['Universe']}, {'name': 'Xin Gao', 'affiliation': ['Xidian University & CQUPT']}, {'name': 'Zhiyong Lu', 'affiliation': ['Deputy Director for Literature Search, NCBI; Senior Investigator, NCBI-NLM']}]
# [{'name': 'M. Temsah', 'affiliation': ['Professor of Pediatrics, Consultant Pediatric Intensivist, King Saud University, Riyadh']}, {'name': 'Ibraheem Altamimi', 'affiliation': ['']}, {'name': 'A. Jamal', 'affiliation': ['PhD Information technology, Kastamonu University,Institute of Materials and Engineering …']}, {'name': 'K. Alhasan', 'affiliation': ['Senior Research Fellow, University of Health and Allied Sciences, Ho Ghana']}, {'name': 'A. Al-Eyadhy', 'affiliation': ['• Professor of Pediatrics, Faculty of Medicine, King Saud University; Consultant Pediatric …']}]
# [{'name': 'Zhixin Li', 'affiliation': ['Guangxi Normal University']}, {'name': 'Ying Xu', 'affiliation': ['GHM Institute of CNS Regeneration, Jinan University']}]
# ...
# [{'name': 'Jeremy V. Pitt', 'affiliation': ['No Affiliation']}]
# [{'name': 'Isabel Fischer', 'affiliation': ['George E. and Mary Lee Fischer Chair in Family Entrepreneurship, University of Louisville']}, {'name': 'Kerry Dobbins', 'affiliation': ['No Affiliation']}]
# [{'name': 'Benedikt Fecher', 'affiliation': ['Alexander von Humboldt Institute for Internet and Society']}, {'name': 'Marcel Hebing', 'affiliation': ['No Affiliation']}, {'name': 'M. Laufer', 'affiliation': ['CVD, University of Maryland']}, {'name': 'Jörg Pohle', 'affiliation': ['Alexander von Humboldt Institute for Internet and Society']}, {'name': 'Fabian Sofsky', 'affiliation': ["Master's student, Technical University of Munich"]}]
# [{'name': 'Eman Alasadi', 'affiliation': ['No Affiliation']}, {'name': 'Carlos R. Baiz', 'affiliation': ['University of Texas at Austin']}]
# [{'name': 'Sabine Brookman-May', 'affiliation': ['Professor Medizin']}, {'name': 'Faiza Farhat', 'affiliation': ['Ph. D.']}, {'name': 'A. Talyshinskii', 'affiliation': ['No Affiliation']}, {'name': 'Nithesh Naik', 'affiliation': ['Manipal Institute of Technology']}, {'name': 'B. Z. Hameed', 'affiliation': ['Clinical Professor of Medicine, University of Otago']}, {'name': 'U. Zhanbyrbekuly', 'affiliation': ['No Affiliation']}, {'name': 'Gafur Khairli', 'affiliation': ['No Affiliation']}, {'name': 'Bakhman Guliev', 'affiliation': ['No Affiliation']}, {'name': 'Patrick Juilebø-Jones', 'affiliation': ['No Affiliation']}, {'name': 'Lazaros Tzelves', 'affiliation': ['No Affiliation']}, {'name': 'Kumar Somani', 'affiliation': ['SENIOR RESEARCH ENGINEER']}]
# [{'name': 'A. Tlili', 'affiliation': ['Associate Professor, Smart Learning Institute of Beijing Normal University']}, {'name': 'Boulus Shehata', 'affiliation': ['Ph.D. Fellow, Smart Learning Institute of Beijing Normal University']}, {'name': 'Michael Agyemang Adarkwah', 'affiliation': ['Beijing Normal University']}, {'name': 'Aras Bozkurt', 'affiliation': ['Anadolu University']}, {'name': 'D. Hickey', 'affiliation': ['Professor, Learning Sciences Program, Indiana University']}, {'name': 'Ronghuai Huang', 'affiliation': ['Smart Learning Institute, Beijing Normal University']}, {'name': 'Brighter Agyemang', 'affiliation': ['UOW']}]
# [{'name': 'Ronald Marquez', 'affiliation': ['Senior Research Associate, North Carolina State University']}, {'name': 'Nelson Barrios', 'affiliation': ['NC State University']}, {'name': 'Ramon E. Vera', 'affiliation': ['Graduate Research Assistant']}, {'name': 'M. E. Mendez', 'affiliation': ['Oregon Shoulder Institute at Southern Oregon Orthopedics']}, {'name': 'Laura Tolosa', 'affiliation': ['Instituto Ramón y Cajal de Investigación Sanitaria']}, {'name': 'Franklin Zambrano', 'affiliation': ['North Carolina State University']}, {'name': 'Yali Li', 'affiliation': ['Function Oncology']}]
# [{'name': 'Carmen C. Richardson', 'affiliation': ['No Affiliation']}, {'name': 'Nicole Oster', 'affiliation': ['Research Assistant, Arizona State University']}, {'name': 'D. Henriksen', 'affiliation': ['Associate Professor of Educational Leadership and Innovation']}, {'name': 'Punya Mishra', 'affiliation': ["Assoc. Dean of Scholarship & Innovation, Mary Lou Fulton Teacher's College, Arizona State"]}]
# [{'name': 'F. Baglivo', 'affiliation': ['LPEN - INECO']}, {'name': 'L. De Angelis', 'affiliation': ['US Geological Survey']}, {'name': 'Virginia Casigliani', 'affiliation': ['University of Pisa']}, {'name': 'G. Arzilli', 'affiliation': ['University of Pisa']}, {'name': 'G. P. Privitera', 'affiliation': ['No Affiliation']}, {'name': 'C. Rizzo', 'affiliation': ['Ospedale Pediatrico Bambino Gesù']}]
# [{'name': 'Abdulrahman M. Al-Zahrani', 'affiliation': ['princess Nourah Bint Abdulrahman University']}]
# [{'name': 'Turgut Karakose', 'affiliation': ['Professor of Educational Administration, Dumlupınar University']}, {'name': 'Murat Demirkol', 'affiliation': ['Fırat Üniversitesi']}, {'name': 'Ramazan Yirci', 'affiliation': ['Sütçü İmam Üniversitesi']}, {'name': 'Hakan Polat', 'affiliation': ['Swedish Polar Research Secretariat']}, {'name': 'Tuncay Yavuz Ozdemir', 'affiliation': ['Fırat Üniversitesi']}, {'name': 'Tijen Tülübaş', 'affiliation': ['Dumlupınar Üniversitesi']}]
# [{'name': 'D. Dalalah', 'affiliation': ['الشريعة الاسلامية، الفقه و اصوله']}, {'name': 'Osama M.A. Dalalah', 'affiliation': ['No Affiliation']}]
# [{'name': 'Cemal Karakas', 'affiliation': ["University of Louisville, Norton Children's Hospital"]}, {'name': 'D. Brock', 'affiliation': ['Goodman School of Business, Brock University']}, {'name': 'Arpita Lakhotia', 'affiliation': ['University of Louisville']}]
# [{'name': 'Jessica G. Borger', 'affiliation': ['WEHI']}, {'name': 'Ashley P Ng', 'affiliation': ['Clinical Translational Fellow, The Walter and Eliza Hall Institute of Medical Research']}, {'name': 'Holly Anderton', 'affiliation': ['College of the Holy Cross']}, {'name': 'George W Ashdown', 'affiliation': ['Walter and Eliza Hall Institute']}, {'name': 'Megan Auld', 'affiliation': ['No Affiliation']}, {'name': 'M. Blewitt', 'affiliation': ['Laboratory head, Walter and Eliza Hall Institute']}, {'name': 'Daniel V Brown', 'affiliation': ['Oregon Department of Environmental Quality']}, {'name': 'Melissa J Call', 'affiliation': ['No Affiliation']}, {'name': 'Peter Collins', 'affiliation': ['Emeritus Professor of Histopathology and Morbid Antomy, University of Cambridge, UK']}, {'name': 'Saskia Freytag', 'affiliation': ['WEHI']}, {'name': 'Leonard C Harrison', 'affiliation': ['Professor of Medicine']}, {'name': 'Eva Hesping', 'affiliation': ['The Walter and Eliza Institute of Medical Research']}, {'name': 'Jaci Hoysted', 'affiliation': ['No Affiliation']}, {'name': 'Anna Johnston', 'affiliation': ['Professor of English and former ARC Future Fellow, University of Queensland']}, {'name': 'Andrew McInneny', 'affiliation': ['No Affiliation']}, {'name': 'Phil Tang', 'affiliation': ['The Chinese University of Hong Kong']}, {'name': 'L. Whitehead', 'affiliation': ['Whitehead Institute']}, {'name': 'A. Jex', 'affiliation': ['The Jackson Laboratory, University of Cambridge']}, {'name': 'S. Naik', 'affiliation': ['Indian Institute of Technology, Delhi']}]
# [{'name': 'Z. Kong', 'affiliation': ['XQ Deng Presidential Chair Professor, The Chinese University of Hong Kong, Shenzhen']}, {'name': 'Vincentius Surya Kurnia Adi', 'affiliation': ['No Affiliation']}, {'name': 'J. Segovia‐Hernández', 'affiliation': ['Universidad de Guanajuato']}, {'name': 'J. Sunarso', 'affiliation': ['Professor, Swinburne University of Technology Sarawak Campus']}]
# [{'name': 'Brayan V. Seixas', 'affiliation': ['Department of Health Policy and Management, UCLA']}, {'name': 'Gabriel R Freitas', 'affiliation': ["D'Or Institute for Research and Education (IDOR) and Universidade Federal Fluminense …"]}]
# [{'name': 'Anik Anekawati', 'affiliation': ['FKIP universitas wiraraja']}, {'name': 'B. Otok', 'affiliation': ['Department of Statistics Institut Teknologi Sepuluh Nopember Surabaya']}, {'name': 'Purhadi', 'affiliation': ['Institut Teknologi Sepuluh Nopember']}, {'name': 'Sutikno', 'affiliation': ['UIN Mataram']}]
# [{'name': 'M. Parkinson', 'affiliation': ["Struthers Parkinson's Center, Park Nicollet Health Services"]}, {'name': 'Ron W Stout', 'affiliation': ['No Affiliation']}, {'name': 'W. Dysinger', 'affiliation': ['No Affiliation']}]
# [{'name': 'Yang Geng', 'affiliation': ['Royal Institute of Technology (KTH), Sweden']}, {'name': 'Zhongchen Zhang', 'affiliation': ['Northeast Agricultural University']}, {'name': 'Juan Yu', 'affiliation': ['USDA']}, {'name': 'Hongzhong Chen', 'affiliation': ['No Affiliation']}, {'name': 'Hao Zhou', 'affiliation': ['LANL']}, {'name': 'B. Lin', 'affiliation': ['Louisiana State University Shreveport']}, {'name': 'Weimin Zhuang', 'affiliation': ['Nanjing University']}]
# [{'name': 'Muhammad Wasif Zafar', 'affiliation': ['Riphah International University']}, {'name': 'S. Zaidi', 'affiliation': ['Memorial Sloan Kettering Cancer Center']}, {'name': 'Sadia Mansoor', 'affiliation': ['Clark University, 950 Main St, Worcester, MA 01610']}, {'name': 'Avik Sinha', 'affiliation': ['Management Development Institute, Gurgaon']}, {'name': 'Quan Qin', 'affiliation': ['Shenzhen University, Wuhan University']}]
# [{'name': 'A. Celone', 'affiliation': ['The University of Sydney']}, {'name': 'Antonello Cammarano', 'affiliation': ['University of Salerno']}, {'name': 'Mauro Caputo', 'affiliation': ['Università degli Studi di Salerno']}, {'name': 'Francesca Michelino', 'affiliation': ['Università degli Studi di salerno']}]
# [{'name': 'Paola Elizabeth Silva Delgado', 'affiliation': ['No Affiliation']}, {'name': 'Antti Kapanen', 'affiliation': ['No Affiliation']}, {'name': 'Soeren Dressler', 'affiliation': ['No Affiliation']}]
# [{'name': 'Mario Alessandri-Bonetti', 'affiliation': ['Department of Plastic, Reconstructive and Aesthetic Surgery, University of Milan']}, {'name': 'Hilary Y Liu', 'affiliation': ['No Affiliation']}, {'name': 'Marco Palmesano', 'affiliation': ['No Affiliation']}, {'name': 'Vu T Nguyen', 'affiliation': ['Computer Science, George Mason University']}, {'name': 'Francesco M Egro', 'affiliation': ['Great Seeds, Granar Group, Paraguay']}]
# [{'name': 'Ying Guo', 'affiliation': ['School of Environment, Jinan University']}, {'name': 'Daniel Lee', 'affiliation': ['The University of Melbourne']}]
# [{'name': 'E. Agathokleous', 'affiliation': ['Professor (full), Nanjing University of Information Science & Technology (NUIST)']}, {'name': 'C. Saitanis', 'affiliation': ['Agricultural University of Athens, Athens, Greece']}, {'name': 'Chao Fang', 'affiliation': ['University of Science and Technology Beijing']}, {'name': 'Zhen Yu', 'affiliation': ['Vice President of JD.COM, Chief Data Scientist of JD Digits, Head of JD Intelligent Cities …']}]
# [{'name': 'G. Sarma', 'affiliation': ['University of Rochester']}, {'name': 'Hrishikesh Kashyap', 'affiliation': ['All India institute of Medical Sciences, Rishikesh']}, {'name': 'P. Medhi', 'affiliation': ['Professor of Human-Anatomy']}]
# [{'name': 'Malik Sallam', 'affiliation': ['Associate Professor, School of Medicine, University of Jordan']}, {'name': 'N. Salim', 'affiliation': ['Department of Botany, Government Arts College (Autonomous), Salem-636 007, Tamil Nadu …']}, {'name': 'Ala’a B. Al-Tammemi', 'affiliation': ['Physician-Scientist in Migration Health']}, {'name': 'M. Barakat', 'affiliation': ['1. King Abdullaziz University (KAU), 2. Central Metallurgical R&D Institute, Egypt']}, {'name': 'Diaa Fayyad', 'affiliation': ['M.Sc of biology']}, {'name': 'S. Hallit', 'affiliation': ['University of Bristol']}, {'name': 'H. Harapan', 'affiliation': ['Medical Research Unit, Tropical Diseases Center, Department of Microbiology, Universitas …']}, {'name': 'R. Hallit', 'affiliation': ['USDA Forest Service']}, {'name': 'A. Mahafzah', 'affiliation': ['Full Professor of Computer Science, The University of Jordan']}]
# [{'name': 'Soha Rawas', 'affiliation': ['PhD, Beirut Arab University']}]
# [{'name': 'K. Lister', 'affiliation': ['Professor of Education and Associate Dean of Equality, Diversity and Inclusion, Arden …']}, {'name': 'E. McPherson', 'affiliation': ['USDA Forest Service']}, {'name': 'Tim Coughlan', 'affiliation': ['Senior Lecturer, Institute of Educational Technology, The Open University']}, {'name': 'A. Gallen', 'affiliation': ['University of St. Gallen']}, {'name': 'V. Pearson', 'affiliation': ['QIMR Berghofer MRI']}]
# [{'name': 'K. Lister', 'affiliation': ['Professor of Education and Associate Dean of Equality, Diversity and Inclusion, Arden …']}, {'name': 'Tim Coughlan', 'affiliation': ['Senior Lecturer, Institute of Educational Technology, The Open University']}, {'name': 'N. Owen', 'affiliation': ['Swinburne University and Baker Heart & Diabetes Institute']}]
# [{'name': 'C. Amedu', 'affiliation': ['No Affiliation']}, {'name': 'B. Ohene-Botwe', 'affiliation': ['CUoL']}]
# [{'name': 'Christian W. F. Mayer', 'affiliation': ['No Affiliation']}, {'name': 'Sabrina Ludwig', 'affiliation': ['Neurochirurgische Klinik und Poliklinik, Ludwig Maximilians Universität München']}, {'name': 'Steffen Brandt', 'affiliation': ['No Affiliation']}]
# [{'name': 'Greeni Maheshwari', 'affiliation': ['RMIT University, Vietnam']}]
# [{'name': 'Johannes Mössinger', 'affiliation': ['No Affiliation']}, {'name': 'C. Troost', 'affiliation': ['Land Use Economics, University of Hohenheim']}, {'name': 'T. Berger', 'affiliation': ['Department of Clinical Psychology, University of Bern, Switzerland']}]
# [{'name': 'Karina Porto da Luz Chianello', 'affiliation': ['No Affiliation']}, {'name': 'Elizabeth Rocha De Souza', 'affiliation': ['Professor do Departamento de Geografia, Universidade Federal do Rio de Janeiro']}]
# [{'name': 'Zahra Khoshnodifar', 'affiliation': ['No Affiliation']}, {'name': 'P. Ataei', 'affiliation': ['PhD']}, {'name': 'Hamid Karimi', 'affiliation': ['Professor, Politecnico di Milano']}]
# [{'name': 'L. F. Alvarado', 'affiliation': ['Centre for Diet and Activity Research, MRC Epidemiology Unit, University of Cambridge']}, {'name': 'Valentín Dávila Macedo', 'affiliation': ['No Affiliation']}, {'name': 'Pedro E. Pérez Peña', 'affiliation': ['No Affiliation']}, {'name': 'Roberto Pezo Díaz', 'affiliation': ['No Affiliation']}, {'name': 'Kember Mejía', 'affiliation': ['No Affiliation']}]
# [{'name': 'Elliott Lauderdale', 'affiliation': ['No Affiliation']}]
# [{'name': 'Natalicio Serrano', 'affiliation': ['University of North Carolina at Chapel Hill']}, {'name': 'L. Perez', 'affiliation': ['ESTUDANTE']}, {'name': 'J. Carlson', 'affiliation': ['Yale University']}, {'name': 'K. Patrick', 'affiliation': ['UC San Diego']}, {'name': 'J. Kerr', 'affiliation': ['John R. Kerr Eminent Scholar Chair in Marketing & Innovation Florida State University']}, {'name': 'C. Holub', 'affiliation': ['No Affiliation']}, {'name': 'E. Arredondo', 'affiliation': ['Professor at San Diego State University']}]
# [{'name': 'Věra Pavlátová', 'affiliation': ['No Affiliation']}]
# [{'name': 'Ugalahi Mary Ogbenyi', 'affiliation': ['College of Medicine,University of Ibadan/ University College Hospital Ibadan']}, {'name': 'Adebusoye Steve Oluwaseun', 'affiliation': ['No Affiliation']}, {'name': 'Olusanya Bolutife Ayokunnu', 'affiliation': ['No Affiliation']}, {'name': 'Baiyeroju Aderonke', 'affiliation': ['PROFESSOR OF OPHTHALMOLOGY, UNIVERSITY OF IBADAN']}]
# [{'name': 'B. Olivier', 'affiliation': ['Penn State University']}]
# [{'name': 'Majeed Kazemitabaar', 'affiliation': ['University of Toronto']}, {'name': 'J. Chow', 'affiliation': ['Dentroid']}, {'name': 'Carl Ka To Ma', 'affiliation': ['No Affiliation']}, {'name': 'B. Ericson', 'affiliation': ['Professor of Radiology, Mayo Clinic']}, {'name': 'David Weintrop', 'affiliation': ['University of Maryland']}, {'name': 'Tovi Grossman', 'affiliation': ['University of Toronto']}]
# [{'name': 'Mukesh Kumar', 'affiliation': ['APIIT']}, {'name': 'Utsav Anand Mani', 'affiliation': ["King George's Medical University"]}, {'name': 'Pranjal Tripathi', 'affiliation': ['Research scholar, IIT BHU']}, {'name': 'Mohd Saalim', 'affiliation': ['']}, {'name': 'Sneha Roy', 'affiliation': ['Dr. BC Roy Engineering College, Durgapur']}]
# [{'name': 'R. Garg', 'affiliation': ['PostDoctoral Fellow, Stanford University']}, {'name': 'V. L. Urs', 'affiliation': ['No Affiliation']}, {'name': 'Akshya Anand Agrawal', 'affiliation': ['No Affiliation']}, {'name': 'Sarvesh Kumar Chaudhary', 'affiliation': ['sgpgims lucknow']}, {'name': 'V. Paliwal', 'affiliation': ['Professor, Department of Neurology, Sanjay Gandhi Postgraduate Institute of Medical …']}, {'name': 'Sujita Kumar Kar', 'affiliation': ['No Affiliation']}]
# [{'name': 'Peifan Li', 'affiliation': ['The University of Hong Kong']}]

# %%
df_clean["Authors"]
# Out:
# 0      [{'name': 'Sophia Spallek', 'affiliation': ['N...
# 1      [{'name': 'Ming Li', 'affiliation': ['Northwes...
# 2      [{'name': 'Junaid Qadir', 'affiliation': ['Pro...
# 3      [{'name': 'Mais Fatayer', 'affiliation': ['Uni...
# 4      [{'name': 'Nishith Reddy Mannuru', 'affiliatio...
#                              ...
# 570    [{'name': 'B. Olivier', 'affiliation': ['Penn ...
# 571    [{'name': 'Majeed Kazemitabaar', 'affiliation'...
# 572    [{'name': 'Mukesh Kumar', 'affiliation': ['API...
# 573    [{'name': 'R. Garg', 'affiliation': ['PostDoct...
# 574    [{'name': 'Peifan Li', 'affiliation': ['The Un...
# Name: Authors, Length: 575, dtype: object

# %%
df_clean["DoiUrl"] = df_clean["DoiUrl"].apply(
    lambda x: x if x != np.nan and type(x) == str and "None" not in x else None
)

# %%
df_clean["PublicationTypes"] = df_clean["PublicationTypes"].apply(
    lambda x: ["".join(t.split("-")).lower() for t in eval(x)]
    if x != np.nan and type(x) == str
    else x
)

# %%
df_clean
# Out:
#                                             PaperTitle  \
# 0    Can we use ChatGPT for Mental Health and Subst...
# 1    Ethical implications of ChatGPT in higher educ...
# 2    Engineering Education in the Era of ChatGPT: P...
# 3    Developing authentic assessment through open e...
# 4    Artificial intelligence in developing countrie...
# ..                                                 ...
# 570  The Covid-19 pandemic: An opportunity for refl...
# 571  Studying the effect of AI Code Generators on S...
# 572  Artificial Hallucinations by Google Bard: Thin...
# 573  Exploring the role of ChatGPT in patient care ...
# 574  AN ANALYSIS OF THE MUSICAL PHILOSOPHY OF MODER...
#
#                                    DOI  \
# 0                        10.2196/51243
# 1            10.48550/arXiv.2311.14378
# 2    10.1109/EDUCON54358.2023.10125121
# 3              10.14742/apubs.2023.657
# 4            10.1177/02666669231200628
# ..                                 ...
# 570  10.17159/2224-7912/2020/V60N4-2A1
# 571            10.1145/3544548.3580919
# 572               10.7759/cureus.43313
# 573        10.1101/2023.06.13.23291311
# 574            10.24204/ejpr.2021.3844
#
#                                                Authors  \
# 0    [{'name': 'Sophia Spallek', 'affiliation': ['N...
# 1    [{'name': 'Ming Li', 'affiliation': ['Northwes...
# 2    [{'name': 'Junaid Qadir', 'affiliation': ['Pro...
# 3    [{'name': 'Mais Fatayer', 'affiliation': ['Uni...
# 4    [{'name': 'Nishith Reddy Mannuru', 'affiliatio...
# ..                                                 ...
# 570  [{'name': 'B. Olivier', 'affiliation': ['Penn ...
# 571  [{'name': 'Majeed Kazemitabaar', 'affiliation'...
# 572  [{'name': 'Mukesh Kumar', 'affiliation': ['API...
# 573  [{'name': 'R. Garg', 'affiliation': ['PostDoct...
# 574  [{'name': 'Peifan Li', 'affiliation': ['The Un...
#
#                                               Abstract Publisher  \
# 0    Background The use of generative artificial in...       NaN
# 1    This scoping review explores the ethical chall...     arXiv
# 2    Engineering education is constantly evolving t...       NaN
# 3    This Pecha Kucha presentation will showcase Th...       NaN
# 4    This paper explores the potential impact of Ge...       NaN
# ..                                                 ...       ...
# 570  The present article poses the question, whethe...       NaN
# 571  AI code generators like OpenAI Codex have the ...       NaN
# 572  One of the critical challenges posed by artifi...       NaN
# 573  Background ChatGPT(Chat Generative Pre-trained...       NaN
# 574  Three variables were considered in this study:...       NaN
#
#                                     SemanticScholarUrl  \
# 0    https://www.semanticscholar.org/paper/083509bb...
# 1    https://www.semanticscholar.org/paper/7611de3f...
# 2    https://www.semanticscholar.org/paper/d553d008...
# 3    https://www.semanticscholar.org/paper/1e0f6f05...
# 4    https://www.semanticscholar.org/paper/5a5e03c3...
# ..                                                 ...
# 570  https://www.semanticscholar.org/paper/f7362485...
# 571  https://www.semanticscholar.org/paper/f03f39f7...
# 572  https://www.semanticscholar.org/paper/0049f577...
# 573  https://www.semanticscholar.org/paper/1c2a3841...
# 574  https://www.semanticscholar.org/paper/2c5426a0...
#
#                                                 DoiUrl PublicationDate  \
# 0                        https://doi.org/10.2196/51243      2023-07-26
# 1            https://doi.org/10.48550/arXiv.2311.14378      2023-11-24
# 2    https://doi.org/10.1109/EDUCON54358.2023.10125121      2023-05-01
# 3              https://doi.org/10.14742/apubs.2023.657      2023-11-28
# 4            https://doi.org/10.1177/02666669231200628      2023-09-14
# ..                                                 ...             ...
# 570  https://doi.org/10.17159/2224-7912/2020/V60N4-2A1             NaN
# 571            https://doi.org/10.1145/3544548.3580919      2023-02-15
# 572               https://doi.org/10.7759/cureus.43313      2023-08-01
# 573        https://doi.org/10.1101/2023.06.13.23291311      2023-06-14
# 574            https://doi.org/10.24204/ejpr.2021.3844      2022-09-10
#
#               FieldOfStudy                                 Conference-Journal  \
# 0             ['Medicine']                             JMIR Medical Education
# 1     ['Computer Science']                                          arXiv.org
# 2     ['Computer Science']       IEEE Global Engineering Education Conference
# 3                      NaN                              ASCILITE Publications
# 4                      NaN                            Information Development
# ..                     ...                                                ...
# 570  ['Political Science']                                                NaN
# 571   ['Computer Science']  International Conference on Human Factors in C...
# 572           ['Medicine']                                             Cureus
# 573           ['Medicine']                                            medRxiv
# 574                    NaN        European Journal for Philosophy of Religion
#
#                          PublicationTypes  \
# 0                        [journalarticle]
# 1                [journalarticle, review]
# 2    [journalarticle, conference, review]
# 3                        [journalarticle]
# 4                        [journalarticle]
# ..                                    ...
# 570                                   NaN
# 571    [journalarticle, book, conference]
# 572           [journalarticle, editorial]
# 573              [journalarticle, review]
# 574                                   NaN
#
#                                           SearchString  CitationCount  \
# 0    "Generative Artificial Intelligence" + "misinf...            0.0
# 1    "Generative Artificial Intelligence" + "misinf...            1.0
# 2    "Generative Artificial Intelligence" + "misinf...          154.0
# 3    "Generative Artificial Intelligence" + "access...            0.0
# 4    "Generative Artificial Intelligence" + "access...            3.0
# ..                                                 ...            ...
# 570                  "PaLM" "responsible" "education"             1.0
# 571               "GPT-3" "over-reliance" "education"            53.0
# 572                "GPT" "misinformation" "education"             4.0
# 573                       "GPT" "privacy" "education"             7.0
# 574              "Claude" "environmental" "education"             2.0
#
#          SearchedFrom
# 0    Semantic Scholar
# 1    Semantic Scholar
# 2    Semantic Scholar
# 3    Semantic Scholar
# 4    Semantic Scholar
# ..                ...
# 570    Web of Science
# 571    Web of Science
# 572    Web of Science
# 573    Web of Science
# 574    Web of Science
#
# [575 rows x 14 columns]

# %%
df_raw = pd.read_csv("./data/cleaned/social/search-results-master-v2.csv")
df_clean = pd.read_csv("./data/cleaned/social/search-results-master-v2-full.csv")

# %%
df_clean.to_csv(filename, index=False)

# %%
pd.merge(df_raw, df_clean, on=["PaperTitle", "SearchString", "SearchedFrom"], how="left").drop_duplicates(subset=["PaperTitle"], keep="last").to_csv("./data/cleaned/social/search-results-master-v2-full.csv", index=False)

# %%
raw_path = './data/cleaned/social/search-results-master-v3-full.csv'
df = pd.read_csv(raw_path)
df.head()
# Out:
#                                           PaperTitle  \
# 0  The Impact of Generative Artificial Intelligen...
# 1  Generative artificial intelligence enhances in...
# 2  The perils and promises of generative artifici...
# 3  Knowledge Management Perspective of Generative...
# 4  Impacts and Risk of Generative AI Technology o...
#
#                          DOI  \
# 0       10.2139/ssrn.4538043
# 1  10.48550/arXiv.2312.00506
# 2   10.1136/jnis-2023-020353
# 3       10.17705/1jais.00859
# 4  10.48550/arXiv.2306.13033
#
#                                              Authors  \
# 0  [{'name': 'Jerry Washington', 'affiliation': [...
# 1  [{'name': 'Anil R. Doshi', 'affiliation': ['As...
# 2  [{'name': 'Tyler R. Ray', 'affiliation': ['Ass...
# 3  [{'name': 'Maryam Alavi', 'affiliation': ['Pro...
# 4  [{'name': 'Subash Neupane', 'affiliation': ['S...
#
#                                             Abstract Publisher  \
# 0  .................................................       NaN
# 1  Creativity is core to being human. Generative ...     arXiv
# 2  Generative artificial intelligence (AI) holds ...       NaN
# 3  In this editorial, revisiting Alavi and Leidne...       NaN
# 4  Generative Artificial Intelligence (GenAI) has...     arXiv
#
#                                   SemanticScholarUrl  \
# 0  https://www.semanticscholar.org/paper/1227f23f...
# 1  https://www.semanticscholar.org/paper/862108e5...
# 2  https://www.semanticscholar.org/paper/c87b18f3...
# 3  https://www.semanticscholar.org/paper/d7a8a922...
# 4  https://www.semanticscholar.org/paper/0b91d11a...
#
#                                       DoiUrl PublicationDate  \
# 0       https://doi.org/10.2139/ssrn.4538043             NaN
# 1  https://doi.org/10.48550/arXiv.2312.00506      2023-12-01
# 2   https://doi.org/10.1136/jnis-2023-020353      2023-07-12
# 3       https://doi.org/10.17705/1jais.00859             NaN
# 4  https://doi.org/10.48550/arXiv.2306.13033      2023-06-22
#
#                         FieldOfStudy                      Conference-Journal  \
# 0                                NaN         Social Science Research Network
# 1  ['Computer Science', 'Economics']                               arXiv.org
# 2                       ['Medicine']  Journal of NeuroInterventional Surgery
# 3                                NaN                      Journal of the AIS
# 4               ['Computer Science']                               arXiv.org
#
#                PublicationTypes  \
# 0  ['journalarticle', 'review']
# 1            ['journalarticle']
# 2            ['journalarticle']
# 3            ['journalarticle']
# 4            ['journalarticle']
#
#                                         SearchString  CitationCount  \
# 0  "Generative Artificial Intelligence" + "over-r...            0.0
# 1  "Generative Artificial Intelligence" + "over-r...            0.0
# 2  "Generative Artificial Intelligence" + "over-r...            2.0
# 3  "Generative Artificial Intelligence" + "over-r...            0.0
# 4  "Generative Artificial Intelligence" + "misinf...            2.0
#
#        SearchedFrom
# 0  Semantic Scholar
# 1  Semantic Scholar
# 2  Semantic Scholar
# 3  Semantic Scholar
# 4  Semantic Scholar

# %%
import pickle

with open("saved_dictionary.pkl", "rb") as f:
    crossref_authors = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 3
#       1 import pickle
# ----> 3 with open("saved_dictionary.pkl", "rb") as f:
#       4     crossref_authors = pickle.load(f)
#
# File ~/projects/publication_scraper/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'saved_dictionary.pkl'

# %%
# crossref_authors = {}
for index, row in df.iterrows():
    print(f"Processing {raw_path}: row {index + 1}/{len(df)}...")
    doi = row["DOI"]
    authors = row["Authors"]

    if type(authors) == str and not pd.isna(authors):
        authors = eval(authors)
    else:
        authors = None

    try:
        crossref_paper = crossref_work.doi(doi)
    except Exception as e:
        print(e)
        crossref_paper = None

    if not authors:
        continue

    if crossref_paper:
        for author in crossref_paper.get("author", []):
            if author["affiliation"] == []:
                continue
            author_name = author.get("given", "") + " " + author.get("family", "")
            if author.get("affiliation"):
                crossref_authors[author_name] = [affil.get("name") for affil in author.get("affiliation")]

    for author in authors:
        if author["affiliation"] == ["No Affiliation"]:
            author_name = author["name"]
            # only get first and last name
            author_name = author_name.split(" ")[0] + " " + author_name.split(" ")[-1]
            if author_name in crossref_authors:
                author["affiliation"] = crossref_authors[author_name]
            else:
                author["affiliation"] = get_affiliations_google_scholar(author_name)

    df.at[index, "Authors"] = authors
# Out:
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 1/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 2/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 3/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 4/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 5/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 6/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 7/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 8/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 9/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 10/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 11/2066...
# Processing ./data/cleaned/social/search-results-master-v3-full.csv: row 12/2066...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 27
#      25         author_name = author.get("given", "") + " " + author.get("family", "")
#      26         if author.get("affiliation"):
# ---> 27             crossref_authors[author_name] = [affil.get("name") for affil in author.get("affiliation")]
#      29 for author in authors:
#      30     if author["affiliation"] == ["No Affiliation"]:
#
# NameError: name 'crossref_authors' is not defined

# %%
df.tail()
# Out:
#                                              PaperTitle  \
# 2061  The power of the natural environment in Nicola...
# 2062  The picturesque roots of impression management...
# 2063  The intervention in the historic plaza de Arma...
# 2064  The VASCERN European Reference Network: An ove...
# 2065  Research Priorities to Advance the Health and ...
#
#                              DOI  \
# 2061         WOS:000497659300003
# 2062   10.1108/aaaj-08-2022-6004
# 2063  10.37230/cytet.2023.216.14
# 2064  10.1016/j.ejmg.2022.104420
# 2065           10.1111/jgs.14943
#
#                                                 Authors  \
# 2061                                                NaN
# 2062  [{'name': 'Karen McBride', 'affiliation': ['Vi...
# 2063  [{'name': 'Carmen Toribio-Marín', 'affiliation...
# 2064  [{'name': 'G. Jondeau', 'affiliation': ['No Af...
# 2065  [{'name': 'M. Tisminetzky', 'affiliation': ['N...
#
#                                                Abstract Publisher  \
# 2061                                                NaN       NaN
# 2062  PurposeThis paper explores the way in which in...       NaN
# 2063  Sobre el recinto multifacético de la antigua p...       NaN
# 2064                                                NaN       NaN
# 2065  To prioritize research topics relevant to the ...       NaN
#
#                                      SemanticScholarUrl  \
# 2061                                                NaN
# 2062  https://www.semanticscholar.org/paper/532efd30...
# 2063  https://www.semanticscholar.org/paper/e610f938...
# 2064  https://www.semanticscholar.org/paper/0487a5ea...
# 2065  https://www.semanticscholar.org/paper/64148276...
#
#                                           DoiUrl PublicationDate  \
# 2061                                         NaN             NaN
# 2062   https://doi.org/10.1108/aaaj-08-2022-6004      2023-12-06
# 2063  https://doi.org/10.37230/cytet.2023.216.14      2023-06-21
# 2064  https://doi.org/10.1016/j.ejmg.2022.104420      2022-01-01
# 2065           https://doi.org/10.1111/jgs.14943      2017-07-01
#
#       FieldOfStudy                                 Conference-Journal  \
# 2061           NaN                                                NaN
# 2062           NaN  Accounting, Auditing &amp; Accountability Journal
# 2063           NaN         Ciudad y Territorio Estudios Territoriales
# 2064  ['Medicine']               European Journal of Medical Genetics
# 2065  ['Medicine']         Journal of The American Geriatrics Society
#
#                   PublicationTypes                        SearchString  \
# 2061                           NaN  "Claude" "environmental" "ethics"
# 2062            ['journalarticle']  "Claude" "environmental" "social"
# 2063            ['journalarticle']  "Claude" "environmental" "social"
# 2064  ['review', 'journalarticle']    "Claude" "responsible" "social"
# 2065            ['journalarticle']    "Claude" "responsible" "social"
#
#       CitationCount    SearchedFrom
# 2061            NaN  Web of Science
# 2062            0.0  Web of Science
# 2063            0.0  Web of Science
# 2064            1.0  Web of Science
# 2065           36.0  Web of Science

# %%
# Saving to a CSV file
df.to_csv(raw_path, index=False)

# %%
import pickle

with open("saved_dictionary.pkl", "wb") as f:
    pickle.dump(crossref_authors, f)

# %% [markdown]
# # Testing stuff

# %%
len(results)
# Out:
# 179

# %%
api_url = "https://api.semanticscholar.org/graph/v1/paper/search/"
headers = {
    "Content-Type": "application/json",
    "x-api-key": "X48LIBLqr86ouHlnMYd3z052sgEm3Nd2wMORPzu5",
}
fields = ["title", "externalIds", "paperId", "url"]
sch_search_string = "Saving the Vicuna: The Political, Biophysical, and Cultural History of Wild Animal Conservation in Peru, 1964-2000"
params = {"query": sch_search_string, "year": "2019-", "fields": ",".join(fields)}
response = requests.get(api_url, headers=headers, params=params)
result = response.json()
print(result)
# Out:
# {'total': 1, 'offset': 0, 'data': [{'paperId': '64fa0be92833e344e79f205976fb77a489461a58', 'externalIds': {'MAG': '3005763097', 'DOI': '10.1093/ahr/rhz939', 'CorpusId': 213377959}, 'url': 'https://www.semanticscholar.org/paper/64fa0be92833e344e79f205976fb77a489461a58', 'title': 'Saving the Vicuña: The Political, Biophysical, and Cultural History of Wild Animal Conservation in Peru, 1964–2000'}]}

# %%
pid = "ArXiv:2205.07144"
api_url = f"https://api.semanticscholar.org/graph/v1/paper/{pid}"
sch_paper = extract_sch(api_url, sch_fields)
sch_paper
# Out:
# {'paperId': 'cb179c916e73c7a6b0edf973b4ed087fe6224722',
#  'externalIds': {'DBLP': 'conf/nips/LiBY22',
#   'ArXiv': '2205.07144',
#   'CorpusId': 248811155},
#  'url': 'https://www.semanticscholar.org/paper/cb179c916e73c7a6b0edf973b4ed087fe6224722',
#  'title': 'Network change point localisation under local differential privacy',
#  'abstract': 'Network data are ubiquitous in our daily life, containing rich but often sensitive information. In this paper, we expand the current static analysis of privatised networks to a dynamic framework by considering a sequence of networks with potential change points. We investigate the fundamental limits in consistently localising change points under both node and edge privacy constraints, demonstrating interesting phase transition in terms of the signal-to-noise ratio condition, accompanied by polynomial-time algorithms. The private signal-to-noise ratio conditions quantify the costs of the privacy for change point localisation problems and exhibit a different scaling in the sparsity parameter compared to the non-private counterparts. Our algorithms are shown to be optimal under the edge LDP constraint up to log factors. Under node LDP constraint, a gap exists between our upper bound and lower bound and we leave it as an interesting open problem.',
#  'venue': 'Neural Information Processing Systems',
#  'citationCount': 4,
#  'fieldsOfStudy': ['Computer Science', 'Mathematics'],
#  'publicationTypes': ['JournalArticle'],
#  'publicationDate': '2022-05-14',
#  'authors': [{'authorId': '2145672500', 'name': 'Mengchu Li'},
#   {'authorId': '10169073', 'name': 'Thomas B. Berrett'},
#   {'authorId': '47111778', 'name': 'Yi Yu'}]}

# %%
# merge the three new csv, on paper title and doi
